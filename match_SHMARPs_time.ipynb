# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from functions import angular_distance
import sys

# %%
def get_data_points_before_start_time(flare, matching_rows, before_start_num):
    if matching_rows.shape[0] == 0:
        shmarp_parameters = pd.DataFrame([0]*len(matching_rows.columns), index=matching_rows.columns).transpose()
        #print('SHMARPs:',shmarp_parameters)
    else:
        t_start = pd.to_datetime(flare['t_start'])
        t_start = t_start - pd.Timedelta(hours=before_start_num)
        shmarp_parameters = matching_rows[pd.to_datetime(matching_rows['T_OBS']) < t_start].iloc[-1:]
        if shmarp_parameters.empty: shmarp_parameters = pd.DataFrame([0]*len(matching_rows.columns), index=matching_rows.columns).transpose()
    return shmarp_parameters

def round_to_n(x,n):
    if np.isnan(x) or x == 0: return x
    else: return round(x, -int(np.floor(np.log10(abs(x)))) + (n - 1))

# %% [markdown]
# Load the SHMARPs dataset

# %%
SHMARPs = pd.read_csv("MERGED_mdi.smarp_cea_96m_1996.04.23_000000_TAI-hmi.sharp_cea_720s_2023.05.09_000000_TAI_v3b.csv") # Read in the data as a single column, skipping the first row (header)
unique_noaa_ar = SHMARPs['NOAA_AR'].unique()
print("Number of unique NOAA_AR in SHMARPs:", len(unique_noaa_ar))
print(SHMARPs.tail(1))
# Out:
# /var/folders/f3/0cy8rn755wb09kvtmdwcsp682r4dkc/T/ipykernel_4890/1398358273.py:1: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   SHMARPs = pd.read_csv("MERGED_mdi.smarp_cea_96m_1996.04.23_000000_TAI-hmi.sharp_cea_720s_2023.05.09_000000_TAI_v3b.csv") # Read in the data as a single column, skipping the first row (header)
# Number of unique NOAA_AR in SHMARPs: 3870
#                                                    DBINDEX  \
# 3354153  hmi.sharp_cea_720s[9520][2023.05.09_00:00:00_TAI]
#
#                        T_OBS     UNIX_TIME  ARPNUM  NOAA_AR NOAA_ARS  CAR_ROT  \
# 3354153  05-09-2023 00:00:05  19486.000058    9520        0      NaN     2270
#
#               USFLUXL  R_VALUE  MEANGBL_GMM  ...       USFLUXZ  CMASKL  \
# 3354153  6.748416e+19      0.0   120.952713  ...  8.574106e+19   421.0
#
#            LAT_FWT  CRLT_OBS    LON_FWT    CRLN_OBS  CDELT1      DSUN_OBS  \
# 3354153  28.806408 -3.392118 -21.547314  117.569489    0.03  1.509737e+11
#
#            RSUN_OBS  QUALITY
# 3354153  950.899353        0
#
# [1 rows x 21 columns]

# %% [markdown]
# Load the Matched Flares-SEP file

# %%
flares = pd.read_csv('flares_matched_manual.dat', sep="\s+", header=0)
unique_ar_flares = flares['AR'].unique()
print("Number of unique NOAA_AR in matched flares file:", unique_ar_flares.shape[0])
# Out:
# Number of unique NOAA_AR in matched flares file: 1178

# %%
common_ar = np.isin(unique_ar_flares, unique_noaa_ar)
print("Number of Active Regions common to both datasets:", np.sum(common_ar))
print(len(unique_noaa_ar))
# Out:
# Number of Active Regions common to both datasets: 872
# 3870

# %% [markdown]
# Append the SHMARP values to the matched Flares-SEP list

# %%
# Initialize empty list to store each row
rows = []
before_start_time = 60 #hours

for index, flare in flares.iterrows():
    matching_rows = SHMARPs[SHMARPs['NOAA_AR'] == flare['AR']] # find the correct AR SHMARP
    shmarp_parameters = get_data_points_before_start_time(flare, matching_rows, before_start_time) # Get the SHMARP datapoint you want
    flare_ = flare.to_frame().T.reset_index(drop=True)  # Convert series to DataFrame, transpose, and reset index
    shmarp_parameters = shmarp_parameters.reset_index(drop=True)  # Reset index
    combined_row = pd.concat([flare_, shmarp_parameters], axis=1)
    combined_row["ANG_DIST_AR"] = angular_distance((combined_row["LAT_FWT"][0], combined_row["LON_FWT"][0]))
    print(combined_row["ANG_DIST_AR"],combined_row["LAT_FWT"][0],combined_row["LON_FWT"][0])
    rows.append(combined_row.values.tolist()[0]) # Convert the combined row to a list or numpy array and append it to rows # .values returns a numpy array, .tolist() converts it to a list
# Out:
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -1.077105
# Name: ANG_DIST_AR, dtype: float64 -11.5 -16.08
# 0   -0.959178
# Name: ANG_DIST_AR, dtype: float64 -11.08 -9.19
# 0   -0.743209
# Name: ANG_DIST_AR, dtype: float64 -10.5 3.49
# 0   -0.609258
# Name: ANG_DIST_AR, dtype: float64 -4.44 10.34
# 0   -0.333082
# Name: ANG_DIST_AR, dtype: float64 -4.48 26.43
# 0   -1.584716
# Name: ANG_DIST_AR, dtype: float64 -23.55 -45.87
# 0   -1.487507
# Name: ANG_DIST_AR, dtype: float64 -23.63 -39.79
# 0   -1.447415
# Name: ANG_DIST_AR, dtype: float64 -23.63 -37.28
# 0   -1.657638
# Name: ANG_DIST_AR, dtype: float64 -28.24 -50.65
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -1.224149
# Name: ANG_DIST_AR, dtype: float64 20.52 -23.73
# 0   -1.187709
# Name: ANG_DIST_AR, dtype: float64 5.07 -22.96
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.786445
# Name: ANG_DIST_AR, dtype: float64 24.59 5.97
# 0   -0.730402
# Name: ANG_DIST_AR, dtype: float64 24.75 10.11
# 0   -1.246679
# Name: ANG_DIST_AR, dtype: float64 -26.52 -24.15
# 0   -1.143604
# Name: ANG_DIST_AR, dtype: float64 21.79 -18.5
# 0   -0.991524
# Name: ANG_DIST_AR, dtype: float64 21.81 -8.87
# 0   -0.977824
# Name: ANG_DIST_AR, dtype: float64 21.82 -7.99
# 0    0.40828
# Name: ANG_DIST_AR, dtype: float64 22.9 49.91
# 0    0.421102
# Name: ANG_DIST_AR, dtype: float64 22.77 53.2
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -1.717575
# Name: ANG_DIST_AR, dtype: float64 -28.72 -54.6
# 0   -1.675832
# Name: ANG_DIST_AR, dtype: float64 -28.32 -51.84
# 0   -1.615618
# Name: ANG_DIST_AR, dtype: float64 -28.41 -47.92
# 0   -1.459354
# Name: ANG_DIST_AR, dtype: float64 16.19 -38.35
# 0   -1.378673
# Name: ANG_DIST_AR, dtype: float64 -19.13 -33.34
# 0   -1.146215
# Name: ANG_DIST_AR, dtype: float64 -19.07 -19.16
# 0   -1.101906
# Name: ANG_DIST_AR, dtype: float64 -19.05 -16.44
# 0   -1.101906
# Name: ANG_DIST_AR, dtype: float64 -19.05 -16.44
# 0   -1.070562
# Name: ANG_DIST_AR, dtype: float64 -18.99 -14.52
# 0   -1.010356
# Name: ANG_DIST_AR, dtype: float64 -18.84 -10.83
# 0   -0.950294
# Name: ANG_DIST_AR, dtype: float64 -18.82 -7.1
# 0   -0.937386
# Name: ANG_DIST_AR, dtype: float64 -18.87 -6.28
# 0   -0.910204
# Name: ANG_DIST_AR, dtype: float64 -18.96 -4.55
# 0   -0.497833
# Name: ANG_DIST_AR, dtype: float64 -19.52 23.78
# 0   -1.040026
# Name: ANG_DIST_AR, dtype: float64 22.78 -11.7
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -1.036585
# Name: ANG_DIST_AR, dtype: float64 19.66 -12.27
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -1.688137
# Name: ANG_DIST_AR, dtype: float64 19.85 -52.15
# 0   -1.280772
# Name: ANG_DIST_AR, dtype: float64 20.19 -27.26
# 0   -1.268096
# Name: ANG_DIST_AR, dtype: float64 20.2 -26.48
# 0   -0.441057
# Name: ANG_DIST_AR, dtype: float64 -22.02 32.28
# 0    0.393089
# Name: ANG_DIST_AR, dtype: float64 -21.96 50.13
# 0   -0.864272
# Name: ANG_DIST_AR, dtype: float64 -22.42 -0.39
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.653305
# Name: ANG_DIST_AR, dtype: float64 -20.88 13.2
# 0   -1.574608
# Name: ANG_DIST_AR, dtype: float64 -24.48 -45.24
# 0   -0.940969
# Name: ANG_DIST_AR, dtype: float64 -24.89 -4.51
# 0   -1.468955
# Name: ANG_DIST_AR, dtype: float64 -23.19 -38.65
# 0   -1.434085
# Name: ANG_DIST_AR, dtype: float64 -23.09 -36.48
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -1.589816
# Name: ANG_DIST_AR, dtype: float64 -24.75 -46.2
# 0   -1.305488
# Name: ANG_DIST_AR, dtype: float64 -24.88 -28.2
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.545689
# Name: ANG_DIST_AR, dtype: float64 -24.57 25.03
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -1.786294
# Name: ANG_DIST_AR, dtype: float64 -16.7 -57.9
# 0   -1.712233
# Name: ANG_DIST_AR, dtype: float64 -16.63 -53.46
# 0   -1.444846
# Name: ANG_DIST_AR, dtype: float64 -16.8 -37.46
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -1.284908
# Name: ANG_DIST_AR, dtype: float64 -16.88 -27.86
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -1.224512
# Name: ANG_DIST_AR, dtype: float64 -16.93 -24.22
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -1.151153
# Name: ANG_DIST_AR, dtype: float64 -16.88 -19.8
# 0   -1.078324
# Name: ANG_DIST_AR, dtype: float64 -16.88 -15.39
# 0   -0.896846
# Name: ANG_DIST_AR, dtype: float64 -17.01 -4.26
# 0   -0.809131
# Name: ANG_DIST_AR, dtype: float64 -16.9 1.16
# 0   -0.423198
# Name: ANG_DIST_AR, dtype: float64 -16.6 27.07
# 0   -0.414226
# Name: ANG_DIST_AR, dtype: float64 -16.68 27.87
# 0   -0.375052
# Name: ANG_DIST_AR, dtype: float64 -16.66 31.23
# 0   -0.375052
# Name: ANG_DIST_AR, dtype: float64 -16.66 31.23
# 0   -0.366579
# Name: ANG_DIST_AR, dtype: float64 -16.68 32.05
# 0   -0.843686
# Name: ANG_DIST_AR, dtype: float64 26.27 2.84
# 0   -0.770453
# Name: ANG_DIST_AR, dtype: float64 26.31 8.18
# 0   -0.758704
# Name: ANG_DIST_AR, dtype: float64 26.33 9.07
# 0   -0.605158
# Name: ANG_DIST_AR, dtype: float64 26.53 21.81
# 0    0.435264
# Name: ANG_DIST_AR, dtype: float64 -16.25 64.18
# 0   -0.499724
# Name: ANG_DIST_AR, dtype: float64 26.87 34.72
# 0   -0.791251
# Name: ANG_DIST_AR, dtype: float64 -31.18 10.25
# 0   -0.446291
# Name: ANG_DIST_AR, dtype: float64 17.44 26.0
# 0   -0.341587
# Name: ANG_DIST_AR, dtype: float64 17.36 35.82
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.312966
# Name: ANG_DIST_AR, dtype: float64 17.34 40.36
# 0   -0.304149
# Name: ANG_DIST_AR, dtype: float64 17.33 43.14
# 0   -1.368704
# Name: ANG_DIST_AR, dtype: float64 -20.33 -32.64
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -1.03644
# Name: ANG_DIST_AR, dtype: float64 18.3 -12.56
# 0   -0.91474
# Name: ANG_DIST_AR, dtype: float64 18.38 -5.0
# 0   -0.701254
# Name: ANG_DIST_AR, dtype: float64 17.72 8.33
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -1.809354
# Name: ANG_DIST_AR, dtype: float64 17.8 -59.37
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -1.738705
# Name: ANG_DIST_AR, dtype: float64 17.64 -55.1
# 0   -1.738705
# Name: ANG_DIST_AR, dtype: float64 17.64 -55.1
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -1.528031
# Name: ANG_DIST_AR, dtype: float64 18.9 -42.41
# 0   -1.244522
# Name: ANG_DIST_AR, dtype: float64 19.04 -25.18
# 0   -1.231324
# Name: ANG_DIST_AR, dtype: float64 19.15 -24.36
# 0   -1.218811
# Name: ANG_DIST_AR, dtype: float64 19.26 -23.58
# 0   -1.20579
# Name: ANG_DIST_AR, dtype: float64 19.28 -22.78
# 0   -1.175902
# Name: ANG_DIST_AR, dtype: float64 19.33 -20.94
# 0   -1.161707
# Name: ANG_DIST_AR, dtype: float64 19.32 -20.07
# 0   -1.161707
# Name: ANG_DIST_AR, dtype: float64 19.32 -20.07
# 0   -1.10982
# Name: ANG_DIST_AR, dtype: float64 19.41 -16.86
# 0   -1.034209
# Name: ANG_DIST_AR, dtype: float64 19.23 -12.22
# 0   -1.022226
# Name: ANG_DIST_AR, dtype: float64 19.3 -11.46
# 0   -0.993871
# Name: ANG_DIST_AR, dtype: float64 19.28 -9.7
# 0   -0.979569
# Name: ANG_DIST_AR, dtype: float64 19.31 -8.8
# 0   -0.965301
# Name: ANG_DIST_AR, dtype: float64 19.34 -7.9
# 0   -0.965301
# Name: ANG_DIST_AR, dtype: float64 19.34 -7.9
# 0   -0.935403
# Name: ANG_DIST_AR, dtype: float64 19.25 -6.05
# 0   -0.895165
# Name: ANG_DIST_AR, dtype: float64 19.33 -3.49
# 0   -0.865749
# Name: ANG_DIST_AR, dtype: float64 19.19 -1.67
# 0   -0.849245
# Name: ANG_DIST_AR, dtype: float64 19.19 -0.62
# 0   -0.793387
# Name: ANG_DIST_AR, dtype: float64 19.08 2.92
# 0   -0.502834
# Name: ANG_DIST_AR, dtype: float64 18.57 22.57
# 0   -0.466388
# Name: ANG_DIST_AR, dtype: float64 18.47 25.34
# 0   -0.380468
# Name: ANG_DIST_AR, dtype: float64 18.67 33.54
# 0    0.339426
# Name: ANG_DIST_AR, dtype: float64 19.21 48.09
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.965333
# Name: ANG_DIST_AR, dtype: float64 -14.94 -8.91
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.952244
# Name: ANG_DIST_AR, dtype: float64 -27.89 -4.0
# 0   -0.952244
# Name: ANG_DIST_AR, dtype: float64 -27.89 -4.0
# 0   -0.952244
# Name: ANG_DIST_AR, dtype: float64 -27.89 -4.0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -1.494993
# Name: ANG_DIST_AR, dtype: float64 -21.54 -40.33
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -1.346129
# Name: ANG_DIST_AR, dtype: float64 19.26 -31.35
# 0   -1.694157
# Name: ANG_DIST_AR, dtype: float64 16.15 -52.36
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.660636
# Name: ANG_DIST_AR, dtype: float64 -24.53 15.22
# 0   -0.622418
# Name: ANG_DIST_AR, dtype: float64 -24.67 18.39
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.523281
# Name: ANG_DIST_AR, dtype: float64 -25.59 28.82
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -1.84489
# Name: ANG_DIST_AR, dtype: float64 19.05 -61.64
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -1.01487
# Name: ANG_DIST_AR, dtype: float64 -25.9 -9.08
# 0   -0.833647
# Name: ANG_DIST_AR, dtype: float64 -26.17 3.5
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -1.845101
# Name: ANG_DIST_AR, dtype: float64 15.55 -61.33
# 0   -1.455039
# Name: ANG_DIST_AR, dtype: float64 23.22 -37.78
# 0   -1.450127
# Name: ANG_DIST_AR, dtype: float64 15.03 -37.84
# 0   -1.179881
# Name: ANG_DIST_AR, dtype: float64 15.23 -21.74
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -1.233229
# Name: ANG_DIST_AR, dtype: float64 -22.33 -24.02
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -1.585456
# Name: ANG_DIST_AR, dtype: float64 21.05 -45.9
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -1.585456
# Name: ANG_DIST_AR, dtype: float64 21.05 -45.9
# 0   -1.060225
# Name: ANG_DIST_AR, dtype: float64 -21.61 -13.29
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -1.060225
# Name: ANG_DIST_AR, dtype: float64 -21.61 -13.29
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -1.284511
# Name: ANG_DIST_AR, dtype: float64 29.07 -26.15
# 0   -1.368533
# Name: ANG_DIST_AR, dtype: float64 29.98 -31.59
# 0   -1.239548
# Name: ANG_DIST_AR, dtype: float64 30.6 -22.8
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -1.761768
# Name: ANG_DIST_AR, dtype: float64 15.85 -56.38
# 0   -0.963425
# Name: ANG_DIST_AR, dtype: float64 20.47 -7.47
# 0   -0.963425
# Name: ANG_DIST_AR, dtype: float64 20.47 -7.47
# 0   -0.963425
# Name: ANG_DIST_AR, dtype: float64 20.47 -7.47
# 0   -0.963425
# Name: ANG_DIST_AR, dtype: float64 20.47 -7.47
# 0   -0.630946
# Name: ANG_DIST_AR, dtype: float64 20.98 14.86
# 0   -0.487038
# Name: ANG_DIST_AR, dtype: float64 21.21 26.43
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -1.467977
# Name: ANG_DIST_AR, dtype: float64 16.02 -38.87
# 0   -1.171668
# Name: ANG_DIST_AR, dtype: float64 20.13 -20.55
# 0   -1.902307
# Name: ANG_DIST_AR, dtype: float64 17.02 -64.9
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.343511
# Name: ANG_DIST_AR, dtype: float64 19.65 43.86
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.637409
# Name: ANG_DIST_AR, dtype: float64 17.5 12.42
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.374674
# Name: ANG_DIST_AR, dtype: float64 -19.86 36.68
# 0   -0.362769
# Name: ANG_DIST_AR, dtype: float64 -19.76 38.42
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -1.011911
# Name: ANG_DIST_AR, dtype: float64 36.03 -4.03
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -1.8019
# Name: ANG_DIST_AR, dtype: float64 26.73 -59.86
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -1.203655
# Name: ANG_DIST_AR, dtype: float64 20.48 -22.47
# 0   -1.078095
# Name: ANG_DIST_AR, dtype: float64 20.36 -14.7
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -1.472802
# Name: ANG_DIST_AR, dtype: float64 -26.2 -38.74
# 0   -1.249335
# Name: ANG_DIST_AR, dtype: float64 -21.63 -25.13
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -1.223237
# Name: ANG_DIST_AR, dtype: float64 -20.95 -23.61
# 0   -1.20872
# Name: ANG_DIST_AR, dtype: float64 -20.63 -22.76
# 0   -0.455021
# Name: ANG_DIST_AR, dtype: float64 19.82 27.71
# 0   -0.406781
# Name: ANG_DIST_AR, dtype: float64 20.03 32.83
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.285474
# Name: ANG_DIST_AR, dtype: float64 -15.83 40.83
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -1.491161
# Name: ANG_DIST_AR, dtype: float64 20.12 -40.14
# 0   -1.468414
# Name: ANG_DIST_AR, dtype: float64 20.15 -38.75
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -1.496097
# Name: ANG_DIST_AR, dtype: float64 -14.94 -40.57
# 0   -1.481096
# Name: ANG_DIST_AR, dtype: float64 -14.95 -39.68
# 0   -1.884038
# Name: ANG_DIST_AR, dtype: float64 -24.78 -64.84
# 0   -1.341971
# Name: ANG_DIST_AR, dtype: float64 -14.97 -31.42
# 0   -1.281257
# Name: ANG_DIST_AR, dtype: float64 -14.97 -27.81
# 0   -0.720723
# Name: ANG_DIST_AR, dtype: float64 19.33 7.77
# 0   -1.210032
# Name: ANG_DIST_AR, dtype: float64 -15.05 -23.56
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.572175
# Name: ANG_DIST_AR, dtype: float64 18.76 17.61
# 0   -1.005551
# Name: ANG_DIST_AR, dtype: float64 -15.07 -11.31
# 0   -1.481681
# Name: ANG_DIST_AR, dtype: float64 -25.1 -39.36
# 0   -1.366966
# Name: ANG_DIST_AR, dtype: float64 -25.04 -32.09
# 0   -0.840205
# Name: ANG_DIST_AR, dtype: float64 -15.01 -1.3
# 0   -0.707906
# Name: ANG_DIST_AR, dtype: float64 -15.14 6.91
# 0   -0.994958
# Name: ANG_DIST_AR, dtype: float64 -25.03 -8.06
# 0   -1.741449
# Name: ANG_DIST_AR, dtype: float64 19.82 -55.4
# 0   -0.729634
# Name: ANG_DIST_AR, dtype: float64 -24.95 10.3
# 0   -0.524269
# Name: ANG_DIST_AR, dtype: float64 -25.26 28.18
# 0   -0.509412
# Name: ANG_DIST_AR, dtype: float64 -25.3 29.94
# 0   -1.1047
# Name: ANG_DIST_AR, dtype: float64 -18.46 -16.72
# 0   -1.210945
# Name: ANG_DIST_AR, dtype: float64 -28.62 -21.35
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.760252
# Name: ANG_DIST_AR, dtype: float64 -29.69 11.53
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -1.556178
# Name: ANG_DIST_AR, dtype: float64 17.87 -44.12
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.894245
# Name: ANG_DIST_AR, dtype: float64 -13.97 -4.82
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -1.883919
# Name: ANG_DIST_AR, dtype: float64 20.35 -64.18
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -1.371304
# Name: ANG_DIST_AR, dtype: float64 20.07 -32.82
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0    0.656114
# Name: ANG_DIST_AR, dtype: float64 37.43 48.78
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.631391
# Name: ANG_DIST_AR, dtype: float64 20.25 14.36
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -1.727643
# Name: ANG_DIST_AR, dtype: float64 -24.19 -54.86
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -1.524839
# Name: ANG_DIST_AR, dtype: float64 -24.33 -42.11
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -1.882749
# Name: ANG_DIST_AR, dtype: float64 22.55 -64.41
# 0   -0.945857
# Name: ANG_DIST_AR, dtype: float64 -14.56 -7.81
# 0   -1.02628
# Name: ANG_DIST_AR, dtype: float64 -24.12 -10.42
# 0   -1.524048
# Name: ANG_DIST_AR, dtype: float64 23.46 -42.08
# 0   -1.427319
# Name: ANG_DIST_AR, dtype: float64 23.5 -36.03
# 0   -0.808983
# Name: ANG_DIST_AR, dtype: float64 -24.07 4.11
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785537
# Name: ANG_DIST_AR, dtype: float64 -24.17 5.8
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -1.272271
# Name: ANG_DIST_AR, dtype: float64 23.46 -26.3
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.647218
# Name: ANG_DIST_AR, dtype: float64 -24.1 15.92
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.412058
# Name: ANG_DIST_AR, dtype: float64 -23.57 43.6
# 0    0.455519
# Name: ANG_DIST_AR, dtype: float64 -23.39 56.92
# 0   -1.233084
# Name: ANG_DIST_AR, dtype: float64 -29.56 -22.61
# 0   -1.563382
# Name: ANG_DIST_AR, dtype: float64 -15.11 -44.56
# 0   -1.563382
# Name: ANG_DIST_AR, dtype: float64 -15.11 -44.56
# 0   -1.505419
# Name: ANG_DIST_AR, dtype: float64 -15.1 -41.12
# 0   -1.000304
# Name: ANG_DIST_AR, dtype: float64 -15.63 -10.89
# 0   -1.743301
# Name: ANG_DIST_AR, dtype: float64 21.21 -55.61
# 0   -1.731503
# Name: ANG_DIST_AR, dtype: float64 21.16 -54.88
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -1.811272
# Name: ANG_DIST_AR, dtype: float64 -22.42 -59.93
# 0   -1.663403
# Name: ANG_DIST_AR, dtype: float64 -22.39 -50.74
# 0   -1.392593
# Name: ANG_DIST_AR, dtype: float64 -22.23 -33.96
# 0   -1.189653
# Name: ANG_DIST_AR, dtype: float64 -22.54 -21.25
# 0   -1.163866
# Name: ANG_DIST_AR, dtype: float64 -22.57 -19.62
# 0   -1.088271
# Name: ANG_DIST_AR, dtype: float64 -22.67 -14.81
# 0   -0.965974
# Name: ANG_DIST_AR, dtype: float64 -22.94 -6.87
# 0   -1.300927
# Name: ANG_DIST_AR, dtype: float64 21.49 -28.35
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -1.031197
# Name: ANG_DIST_AR, dtype: float64 19.55 -11.96
# 0   -0.394828
# Name: ANG_DIST_AR, dtype: float64 15.14 27.99
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0    0.35885
# Name: ANG_DIST_AR, dtype: float64 20.52 46.32
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -1.713103
# Name: ANG_DIST_AR, dtype: float64 19.06 -53.63
# 0   -1.687149
# Name: ANG_DIST_AR, dtype: float64 18.94 -52.05
# 0   -1.600887
# Name: ANG_DIST_AR, dtype: float64 18.68 -46.82
# 0   -1.554912
# Name: ANG_DIST_AR, dtype: float64 18.56 -44.04
# 0   -1.542843
# Name: ANG_DIST_AR, dtype: float64 18.61 -43.31
# 0   -1.36533
# Name: ANG_DIST_AR, dtype: float64 16.72 -32.7
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.518549
# Name: ANG_DIST_AR, dtype: float64 14.89 18.99
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -1.878404
# Name: ANG_DIST_AR, dtype: float64 -24.96 -64.51
# 0   -1.34683
# Name: ANG_DIST_AR, dtype: float64 -11.29 -31.91
# 0   -1.241234
# Name: ANG_DIST_AR, dtype: float64 -11.15 -25.74
# 0    0.263841
# Name: ANG_DIST_AR, dtype: float64 -13.98 50.81
# 0   -1.565882
# Name: ANG_DIST_AR, dtype: float64 -13.88 -44.71
# 0   -1.483047
# Name: ANG_DIST_AR, dtype: float64 -14.35 -39.81
# 0   -1.669892
# Name: ANG_DIST_AR, dtype: float64 11.28 -50.79
# 0   -0.893512
# Name: ANG_DIST_AR, dtype: float64 -17.1 -4.03
# 0   -0.868293
# Name: ANG_DIST_AR, dtype: float64 -17.16 -2.45
# 0   -0.577134
# Name: ANG_DIST_AR, dtype: float64 -17.83 16.68
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -1.636579
# Name: ANG_DIST_AR, dtype: float64 16.44 -48.93
# 0   -1.63523
# Name: ANG_DIST_AR, dtype: float64 15.96 -48.84
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -1.175097
# Name: ANG_DIST_AR, dtype: float64 14.75 -21.51
# 0   -1.162114
# Name: ANG_DIST_AR, dtype: float64 14.8 -20.73
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -1.900204
# Name: ANG_DIST_AR, dtype: float64 -12.88 -64.38
# 0   -0.768351
# Name: ANG_DIST_AR, dtype: float64 13.77 2.76
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -1.756239
# Name: ANG_DIST_AR, dtype: float64 -12.82 -55.9
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -1.560762
# Name: ANG_DIST_AR, dtype: float64 -12.99 -44.41
# 0   -1.48326
# Name: ANG_DIST_AR, dtype: float64 -13.11 -39.85
# 0   -1.423128
# Name: ANG_DIST_AR, dtype: float64 -13.14 -36.31
# 0   -1.800212
# Name: ANG_DIST_AR, dtype: float64 18.32 -58.86
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.27912
# Name: ANG_DIST_AR, dtype: float64 11.82 34.15
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.954767
# Name: ANG_DIST_AR, dtype: float64 -13.0 -8.63
# 0   -0.954767
# Name: ANG_DIST_AR, dtype: float64 -13.0 -8.63
# 0   -0.954767
# Name: ANG_DIST_AR, dtype: float64 -13.0 -8.63
# 0   -1.749114
# Name: ANG_DIST_AR, dtype: float64 -11.54 -55.43
# 0   -1.747651
# Name: ANG_DIST_AR, dtype: float64 -12.94 -55.4
# 0   -0.75164
# Name: ANG_DIST_AR, dtype: float64 -14.73 4.06
# 0   -0.69778
# Name: ANG_DIST_AR, dtype: float64 -14.87 7.45
# 0   -1.646766
# Name: ANG_DIST_AR, dtype: float64 -13.14 -49.47
# 0   -1.634695
# Name: ANG_DIST_AR, dtype: float64 -13.16 -48.76
# 0   -1.625008
# Name: ANG_DIST_AR, dtype: float64 -13.16 -48.19
# 0   -0.583467
# Name: ANG_DIST_AR, dtype: float64 -15.09 14.81
# 0   -0.530027
# Name: ANG_DIST_AR, dtype: float64 -15.09 18.33
# 0   -0.516982
# Name: ANG_DIST_AR, dtype: float64 -15.08 19.2
# 0   -1.452049
# Name: ANG_DIST_AR, dtype: float64 -13.9 -37.99
# 0   -0.44253
# Name: ANG_DIST_AR, dtype: float64 -15.13 24.41
# 0   -0.348159
# Name: ANG_DIST_AR, dtype: float64 -15.1 31.81
# 0   -1.251485
# Name: ANG_DIST_AR, dtype: float64 -13.81 -26.14
# 0   -0.331864
# Name: ANG_DIST_AR, dtype: float64 -15.11 33.32
# 0   -0.29734
# Name: ANG_DIST_AR, dtype: float64 -14.99 36.81
# 0   -0.259603
# Name: ANG_DIST_AR, dtype: float64 -14.78 43.31
# 0    0.258981
# Name: ANG_DIST_AR, dtype: float64 -14.82 45.75
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -1.817439
# Name: ANG_DIST_AR, dtype: float64 11.74 -59.44
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -1.80817
# Name: ANG_DIST_AR, dtype: float64 18.18 -59.33
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -1.590602
# Name: ANG_DIST_AR, dtype: float64 17.52 -46.19
# 0   -0.784952
# Name: ANG_DIST_AR, dtype: float64 17.64 2.93
# 0   -0.704029
# Name: ANG_DIST_AR, dtype: float64 17.65 8.12
# 0   -0.627089
# Name: ANG_DIST_AR, dtype: float64 17.76 13.24
# 0   -0.52604
# Name: ANG_DIST_AR, dtype: float64 17.83 20.29
# 0   -0.491391
# Name: ANG_DIST_AR, dtype: float64 17.85 22.86
# 0   -0.345051
# Name: ANG_DIST_AR, dtype: float64 18.51 37.93
# 0   -1.539273
# Name: ANG_DIST_AR, dtype: float64 -16.11 -43.12
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.793132
# Name: ANG_DIST_AR, dtype: float64 -15.27 1.66
# 0   -1.463078
# Name: ANG_DIST_AR, dtype: float64 -17.98 -38.51
# 0   -0.605998
# Name: ANG_DIST_AR, dtype: float64 -18.08 14.84
# 0   -1.09354
# Name: ANG_DIST_AR, dtype: float64 -29.2 -13.25
# 0   -0.71416
# Name: ANG_DIST_AR, dtype: float64 -29.53 15.28
# 0   -0.705264
# Name: ANG_DIST_AR, dtype: float64 -29.56 16.09
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.72062
# Name: ANG_DIST_AR, dtype: float64 24.98 10.99
# 0   -1.74165
# Name: ANG_DIST_AR, dtype: float64 25.74 -55.88
# 0   -1.701267
# Name: ANG_DIST_AR, dtype: float64 26.1 -53.33
# 0   -1.377526
# Name: ANG_DIST_AR, dtype: float64 26.38 -32.62
# 0   -0.984921
# Name: ANG_DIST_AR, dtype: float64 26.22 -6.95
# 0   -1.162598
# Name: ANG_DIST_AR, dtype: float64 -24.93 -19.04
# 0   -1.459948
# Name: ANG_DIST_AR, dtype: float64 -28.77 -37.75
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.738979
# Name: ANG_DIST_AR, dtype: float64 -23.3 8.59
# 0   -0.360019
# Name: ANG_DIST_AR, dtype: float64 -20.6 43.91
# 0    0.359545
# Name: ANG_DIST_AR, dtype: float64 -20.59 45.67
# 0   -1.116487
# Name: ANG_DIST_AR, dtype: float64 22.05 -16.74
# 0   -1.89453
# Name: ANG_DIST_AR, dtype: float64 20.25 -64.82
# 0   -0.345407
# Name: ANG_DIST_AR, dtype: float64 -14.15 31.02
# 0   -0.573168
# Name: ANG_DIST_AR, dtype: float64 -15.8 15.83
# 0   -0.523447
# Name: ANG_DIST_AR, dtype: float64 -15.83 19.19
# 0   -0.509481
# Name: ANG_DIST_AR, dtype: float64 -15.83 20.15
# 0   -0.436731
# Name: ANG_DIST_AR, dtype: float64 -15.91 25.43
# 0    0.258617
# Name: ANG_DIST_AR, dtype: float64 -13.92 50.13
# 0   -0.304546
# Name: ANG_DIST_AR, dtype: float64 -15.95 37.83
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -1.85976
# Name: ANG_DIST_AR, dtype: float64 -14.53 -62.12
# 0   -1.85976
# Name: ANG_DIST_AR, dtype: float64 -14.53 -62.12
# 0   -1.598675
# Name: ANG_DIST_AR, dtype: float64 -14.51 -46.65
# 0   -1.714193
# Name: ANG_DIST_AR, dtype: float64 -15.05 -53.51
# 0   -1.714193
# Name: ANG_DIST_AR, dtype: float64 -15.05 -53.51
# 0   -0.350028
# Name: ANG_DIST_AR, dtype: float64 -15.81 32.5
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -1.889449
# Name: ANG_DIST_AR, dtype: float64 -16.39 -64.06
# 0   -1.75148
# Name: ANG_DIST_AR, dtype: float64 -16.46 -55.8
# 0   -1.622342
# Name: ANG_DIST_AR, dtype: float64 -16.48 -48.08
# 0   -1.520754
# Name: ANG_DIST_AR, dtype: float64 -16.47 -42.01
# 0   -1.083104
# Name: ANG_DIST_AR, dtype: float64 -16.88 -15.68
# 0   -1.026735
# Name: ANG_DIST_AR, dtype: float64 -16.95 -12.24
# 0   -0.945474
# Name: ANG_DIST_AR, dtype: float64 -16.95 -7.27
# 0   -0.681795
# Name: ANG_DIST_AR, dtype: float64 -16.92 9.25
# 0   -0.429301
# Name: ANG_DIST_AR, dtype: float64 -17.05 27.0
# 0   -1.265618
# Name: ANG_DIST_AR, dtype: float64 -30.46 -24.6
# 0   -1.227145
# Name: ANG_DIST_AR, dtype: float64 10.21 -24.98
# 0   -0.408496
# Name: ANG_DIST_AR, dtype: float64 -17.03 28.7
# 0   -0.317744
# Name: ANG_DIST_AR, dtype: float64 -16.84 37.98
# 0   -0.301188
# Name: ANG_DIST_AR, dtype: float64 -16.85 41.22
# 0   -0.877108
# Name: ANG_DIST_AR, dtype: float64 10.8 -4.39
# 0   -0.831845
# Name: ANG_DIST_AR, dtype: float64 10.87 -1.7
# 0   -0.994367
# Name: ANG_DIST_AR, dtype: float64 32.65 -4.66
# 0   -0.524976
# Name: ANG_DIST_AR, dtype: float64 11.17 16.89
# 0   -0.37472
# Name: ANG_DIST_AR, dtype: float64 11.36 26.66
# 0   -0.26164
# Name: ANG_DIST_AR, dtype: float64 11.51 35.33
# 0    0.210368
# Name: ANG_DIST_AR, dtype: float64 11.92 46.8
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.447249
# Name: ANG_DIST_AR, dtype: float64 -10.04 21.3
# 0   -0.20691
# Name: ANG_DIST_AR, dtype: float64 -10.1 38.76
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.954074
# Name: ANG_DIST_AR, dtype: float64 -16.81 -7.83
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -1.51079
# Name: ANG_DIST_AR, dtype: float64 -18.23 -41.38
# 0   -1.471065
# Name: ANG_DIST_AR, dtype: float64 -18.31 -38.98
# 0   -1.471065
# Name: ANG_DIST_AR, dtype: float64 -18.31 -38.98
# 0   -1.427697
# Name: ANG_DIST_AR, dtype: float64 -18.32 -36.36
# 0   -1.415249
# Name: ANG_DIST_AR, dtype: float64 -18.28 -35.61
# 0   -1.392922
# Name: ANG_DIST_AR, dtype: float64 -18.29 -34.26
# 0   -1.344823
# Name: ANG_DIST_AR, dtype: float64 -18.3 -31.35
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.354085
# Name: ANG_DIST_AR, dtype: float64 18.04 35.56
# 0   -0.348703
# Name: ANG_DIST_AR, dtype: float64 -14.36 30.96
# 0    0.247592
# Name: ANG_DIST_AR, dtype: float64 -14.15 46.02
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.614069
# Name: ANG_DIST_AR, dtype: float64 -22.54 17.24
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.44152
# Name: ANG_DIST_AR, dtype: float64 -22.84 33.82
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.435716
# Name: ANG_DIST_AR, dtype: float64 -22.84 34.64
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -1.456857
# Name: ANG_DIST_AR, dtype: float64 -18.36 -38.12
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -1.869037
# Name: ANG_DIST_AR, dtype: float64 18.22 -63.02
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.895894
# Name: ANG_DIST_AR, dtype: float64 -17.68 -4.02
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.513993
# Name: ANG_DIST_AR, dtype: float64 -17.3 20.79
# 0   -0.513993
# Name: ANG_DIST_AR, dtype: float64 -17.3 20.79
# 0   -0.741651
# Name: ANG_DIST_AR, dtype: float64 16.65 5.32
# 0   -0.323905
# Name: ANG_DIST_AR, dtype: float64 -16.73 36.85
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -1.756331
# Name: ANG_DIST_AR, dtype: float64 -18.99 -56.25
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -1.756226
# Name: ANG_DIST_AR, dtype: float64 8.0 -55.73
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.894977
# Name: ANG_DIST_AR, dtype: float64 -16.09 -4.38
# 0   -0.80989
# Name: ANG_DIST_AR, dtype: float64 -30.41 8.09
# 0   -0.686764
# Name: ANG_DIST_AR, dtype: float64 -14.73 8.09
# 0   -1.599085
# Name: ANG_DIST_AR, dtype: float64 20.46 -46.73
# 0   -1.599085
# Name: ANG_DIST_AR, dtype: float64 20.46 -46.73
# 0   -1.587149
# Name: ANG_DIST_AR, dtype: float64 20.45 -46.0
# 0   -1.587149
# Name: ANG_DIST_AR, dtype: float64 20.45 -46.0
# 0   -0.585908
# Name: ANG_DIST_AR, dtype: float64 -31.61 33.06
# 0   -1.363034
# Name: ANG_DIST_AR, dtype: float64 20.36 -32.29
# 0   -0.801483
# Name: ANG_DIST_AR, dtype: float64 20.74 3.06
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.818884
# Name: ANG_DIST_AR, dtype: float64 21.47 2.22
# 0   -0.599642
# Name: ANG_DIST_AR, dtype: float64 21.35 17.42
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -1.858798
# Name: ANG_DIST_AR, dtype: float64 20.14 -62.61
# 0   -0.407556
# Name: ANG_DIST_AR, dtype: float64 21.54 35.76
# 0    0.381491
# Name: ANG_DIST_AR, dtype: float64 21.73 47.42
# 0   -1.173228
# Name: ANG_DIST_AR, dtype: float64 21.16 -20.47
# 0   -0.517426
# Name: ANG_DIST_AR, dtype: float64 7.27 16.18
# 0   -1.136814
# Name: ANG_DIST_AR, dtype: float64 21.36 -18.16
# 0   -0.656959
# Name: ANG_DIST_AR, dtype: float64 14.43 9.85
# 0   -0.876622
# Name: ANG_DIST_AR, dtype: float64 21.58 -1.53
# 0   -1.680069
# Name: ANG_DIST_AR, dtype: float64 15.87 -51.51
# 0   -0.867343
# Name: ANG_DIST_AR, dtype: float64 21.59 -0.92
# 0   -0.593039
# Name: ANG_DIST_AR, dtype: float64 21.51 18.04
# 0   -1.01536
# Name: ANG_DIST_AR, dtype: float64 19.69 -10.94
# 0   -0.549459
# Name: ANG_DIST_AR, dtype: float64 21.52 21.45
# 0   -0.49014
# Name: ANG_DIST_AR, dtype: float64 21.52 26.51
# 0   -0.374527
# Name: ANG_DIST_AR, dtype: float64 21.45 44.37
# 0   -0.575807
# Name: ANG_DIST_AR, dtype: float64 19.49 17.84
# 0   -1.306015
# Name: ANG_DIST_AR, dtype: float64 12.03 -29.48
# 0    0.366064
# Name: ANG_DIST_AR, dtype: float64 20.94 46.22
# 0   -1.296394
# Name: ANG_DIST_AR, dtype: float64 15.23 -28.69
# 0   -0.841021
# Name: ANG_DIST_AR, dtype: float64 22.98 1.4
# 0   -0.788023
# Name: ANG_DIST_AR, dtype: float64 23.04 5.03
# 0   -1.12486
# Name: ANG_DIST_AR, dtype: float64 16.88 -18.21
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.694123
# Name: ANG_DIST_AR, dtype: float64 18.25 9.03
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.612318
# Name: ANG_DIST_AR, dtype: float64 18.19 14.47
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.546412
# Name: ANG_DIST_AR, dtype: float64 18.35 19.18
# 0   -1.828571
# Name: ANG_DIST_AR, dtype: float64 18.02 -60.55
# 0   -1.788378
# Name: ANG_DIST_AR, dtype: float64 18.01 -58.12
# 0   -0.409478
# Name: ANG_DIST_AR, dtype: float64 18.46 30.26
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.335541
# Name: ANG_DIST_AR, dtype: float64 18.26 38.88
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.319563
# Name: ANG_DIST_AR, dtype: float64 18.08 42.06
# 0   -0.314964
# Name: ANG_DIST_AR, dtype: float64 18.01 43.84
# 0   -1.353889
# Name: ANG_DIST_AR, dtype: float64 18.02 -31.92
# 0   -1.312706
# Name: ANG_DIST_AR, dtype: float64 18.03 -29.43
# 0   -1.18831
# Name: ANG_DIST_AR, dtype: float64 18.1 -21.88
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.987488
# Name: ANG_DIST_AR, dtype: float64 -10.36 -10.95
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.81092
# Name: ANG_DIST_AR, dtype: float64 18.35 1.53
# 0   -0.799233
# Name: ANG_DIST_AR, dtype: float64 18.31 2.26
# 0   -1.790845
# Name: ANG_DIST_AR, dtype: float64 -13.09 -57.95
# 0   -1.727822
# Name: ANG_DIST_AR, dtype: float64 -12.85 -54.23
# 0   -0.773716
# Name: ANG_DIST_AR, dtype: float64 18.2 3.85
# 0   -1.586432
# Name: ANG_DIST_AR, dtype: float64 -13.15 -45.92
# 0   -1.586432
# Name: ANG_DIST_AR, dtype: float64 -13.15 -45.92
# 0   -0.692815
# Name: ANG_DIST_AR, dtype: float64 18.06 9.03
# 0   -1.485183
# Name: ANG_DIST_AR, dtype: float64 -13.26 -39.96
# 0   -1.306989
# Name: ANG_DIST_AR, dtype: float64 -13.27 -29.46
# 0   -1.273834
# Name: ANG_DIST_AR, dtype: float64 -13.32 -27.5
# 0   -1.778453
# Name: ANG_DIST_AR, dtype: float64 12.05 -57.17
# 0   -1.715713
# Name: ANG_DIST_AR, dtype: float64 12.0 -53.49
# 0   -1.192885
# Name: ANG_DIST_AR, dtype: float64 -13.29 -22.72
# 0   -1.667299
# Name: ANG_DIST_AR, dtype: float64 11.85 -50.65
# 0   -1.587036
# Name: ANG_DIST_AR, dtype: float64 11.63 -45.95
# 0   -1.055634
# Name: ANG_DIST_AR, dtype: float64 -13.41 -14.57
# 0   -1.560882
# Name: ANG_DIST_AR, dtype: float64 11.66 -44.42
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -1.396813
# Name: ANG_DIST_AR, dtype: float64 11.64 -34.82
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.644467
# Name: ANG_DIST_AR, dtype: float64 -12.91 10.1
# 0   -0.586841
# Name: ANG_DIST_AR, dtype: float64 -12.8 13.64
# 0   -1.310761
# Name: ANG_DIST_AR, dtype: float64 6.58 -30.0
# 0   -0.29126
# Name: ANG_DIST_AR, dtype: float64 -13.1 34.57
# 0   -1.163142
# Name: ANG_DIST_AR, dtype: float64 6.56 -21.48
# 0   -0.343359
# Name: ANG_DIST_AR, dtype: float64 12.06 29.34
# 0   -0.768676
# Name: ANG_DIST_AR, dtype: float64 13.88 2.77
# 0   -0.827076
# Name: ANG_DIST_AR, dtype: float64 24.05 2.85
# 0   -0.726511
# Name: ANG_DIST_AR, dtype: float64 17.33 6.54
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -1.722957
# Name: ANG_DIST_AR, dtype: float64 -18.55 -54.2
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.298239
# Name: ANG_DIST_AR, dtype: float64 9.01 30.42
# 0   -1.653306
# Name: ANG_DIST_AR, dtype: float64 -20.26 -50.04
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -1.623119
# Name: ANG_DIST_AR, dtype: float64 14.74 -48.1
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -1.446155
# Name: ANG_DIST_AR, dtype: float64 14.57 -37.62
# 0   -1.42244
# Name: ANG_DIST_AR, dtype: float64 14.45 -36.22
# 0   -1.402292
# Name: ANG_DIST_AR, dtype: float64 14.38 -35.03
# 0   -1.379186
# Name: ANG_DIST_AR, dtype: float64 14.22 -33.67
# 0   -1.355117
# Name: ANG_DIST_AR, dtype: float64 14.14 -32.25
# 0   -1.342045
# Name: ANG_DIST_AR, dtype: float64 14.08 -31.48
# 0   -1.323102
# Name: ANG_DIST_AR, dtype: float64 13.91 -30.37
# 0   -1.23065
# Name: ANG_DIST_AR, dtype: float64 13.99 -24.89
# 0   -1.218362
# Name: ANG_DIST_AR, dtype: float64 13.9 -24.17
# 0   -1.180562
# Name: ANG_DIST_AR, dtype: float64 13.79 -21.94
# 0   -1.16621
# Name: ANG_DIST_AR, dtype: float64 13.87 -21.08
# 0   -1.159041
# Name: ANG_DIST_AR, dtype: float64 13.91 -20.65
# 0   -1.121779
# Name: ANG_DIST_AR, dtype: float64 14.04 -18.42
# 0   -1.110878
# Name: ANG_DIST_AR, dtype: float64 14.05 -17.77
# 0   -1.110878
# Name: ANG_DIST_AR, dtype: float64 14.05 -17.77
# 0   -1.098819
# Name: ANG_DIST_AR, dtype: float64 13.99 -17.06
# 0   -1.061003
# Name: ANG_DIST_AR, dtype: float64 13.9 -14.82
# 0   -0.60406
# Name: ANG_DIST_AR, dtype: float64 13.54 12.84
# 0   -1.728343
# Name: ANG_DIST_AR, dtype: float64 11.4 -54.21
# 0   -1.700301
# Name: ANG_DIST_AR, dtype: float64 11.39 -52.57
# 0   -1.644725
# Name: ANG_DIST_AR, dtype: float64 11.32 -49.32
# 0   -1.563435
# Name: ANG_DIST_AR, dtype: float64 11.22 -44.57
# 0   -1.549736
# Name: ANG_DIST_AR, dtype: float64 11.18 -43.77
# 0   -1.508638
# Name: ANG_DIST_AR, dtype: float64 11.15 -41.37
# 0   -1.422131
# Name: ANG_DIST_AR, dtype: float64 11.05 -36.32
# 0   -0.628175
# Name: ANG_DIST_AR, dtype: float64 -12.8 11.07
# 0   -0.449607
# Name: ANG_DIST_AR, dtype: float64 -12.83 22.47
# 0   -1.15592
# Name: ANG_DIST_AR, dtype: float64 11.07 -20.75
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0    0.234691
# Name: ANG_DIST_AR, dtype: float64 10.45 53.51
# 0    0.27816
# Name: ANG_DIST_AR, dtype: float64 10.25 57.27
# 0   -1.779364
# Name: ANG_DIST_AR, dtype: float64 -8.35 -57.08
# 0   -1.836673
# Name: ANG_DIST_AR, dtype: float64 -21.38 -61.39
# 0   -1.643151
# Name: ANG_DIST_AR, dtype: float64 -8.34 -49.19
# 0   -0.586167
# Name: ANG_DIST_AR, dtype: float64 29.03 27.32
# 0   -0.540508
# Name: ANG_DIST_AR, dtype: float64 28.99 33.6
# 0   -1.181399
# Name: ANG_DIST_AR, dtype: float64 1.6 -22.68
# 0   -1.166751
# Name: ANG_DIST_AR, dtype: float64 1.63 -21.84
# 0   -1.135178
# Name: ANG_DIST_AR, dtype: float64 1.64 -20.03
# 0   -1.069421
# Name: ANG_DIST_AR, dtype: float64 1.67 -16.26
# 0   -0.354013
# Name: ANG_DIST_AR, dtype: float64 2.09 24.82
# 0    0.04999
# Name: ANG_DIST_AR, dtype: float64 2.26 46.76
# 0    0.336502
# Name: ANG_DIST_AR, dtype: float64 2.68 64.1
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -1.308455
# Name: ANG_DIST_AR, dtype: float64 13.52 -29.53
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.584707
# Name: ANG_DIST_AR, dtype: float64 10.32 12.95
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -1.571138
# Name: ANG_DIST_AR, dtype: float64 -11.74 -45.02
# 0    0.537633
# Name: ANG_DIST_AR, dtype: float64 24.33 64.5
# 0   -0.219102
# Name: ANG_DIST_AR, dtype: float64 12.24 42.19
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -1.864071
# Name: ANG_DIST_AR, dtype: float64 -22.54 -63.24
# ...
# 0   -0.345734
# Name: ANG_DIST_AR, dtype: float64 -19.72352 43.123016
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.70861
# Name: ANG_DIST_AR, dtype: float64 -17.824373 7.896759
# 0   -0.70388
# Name: ANG_DIST_AR, dtype: float64 -17.835218 8.208787
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -1.740808
# Name: ANG_DIST_AR, dtype: float64 -14.53129 -55.066139
# 0   -1.690597
# Name: ANG_DIST_AR, dtype: float64 -14.544413 -52.092518
# 0   -1.639404
# Name: ANG_DIST_AR, dtype: float64 -14.547256 -49.061329
# 0   -1.484648
# Name: ANG_DIST_AR, dtype: float64 15.489225 -39.87759
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.67194
# Name: ANG_DIST_AR, dtype: float64 24.011978 13.95458
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -1.177583
# Name: ANG_DIST_AR, dtype: float64 -14.617649 -21.673149
# 0   -1.077475
# Name: ANG_DIST_AR, dtype: float64 16.100405 -15.469553
# 0   -0.234611
# Name: ANG_DIST_AR, dtype: float64 -13.299261 43.026833
# 0   -0.233248
# Name: ANG_DIST_AR, dtype: float64 -13.30442 43.726742
# 0   -0.231858
# Name: ANG_DIST_AR, dtype: float64 -13.279595 44.636047
# 0   -1.679391
# Name: ANG_DIST_AR, dtype: float64 15.297489 -51.451557
# 0   -0.756457
# Name: ANG_DIST_AR, dtype: float64 -14.89257 3.811844
# 0   -0.551215
# Name: ANG_DIST_AR, dtype: float64 -24.819527 24.814634
# 0   -0.475816
# Name: ANG_DIST_AR, dtype: float64 -24.895527 33.516541
# 0   -0.440121
# Name: ANG_DIST_AR, dtype: float64 -24.935402 41.115108
# 0   -0.434907
# Name: ANG_DIST_AR, dtype: float64 17.751539 27.222273
# 0   -0.433141
# Name: ANG_DIST_AR, dtype: float64 17.735659 27.353193
# 0   -0.353232
# Name: ANG_DIST_AR, dtype: float64 17.712524 35.047485
# 0   -0.332903
# Name: ANG_DIST_AR, dtype: float64 17.720745 37.827568
# 0   -0.316986
# Name: ANG_DIST_AR, dtype: float64 17.833942 41.506599
# 0   -0.313828
# Name: ANG_DIST_AR, dtype: float64 17.96887 44.327305
# 0   -1.735171
# Name: ANG_DIST_AR, dtype: float64 21.743227 -55.146755
# 0    0.341111
# Name: ANG_DIST_AR, dtype: float64 18.494217 51.433445
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.454691
# Name: ANG_DIST_AR, dtype: float64 14.836068 23.338406
# 0   -0.454691
# Name: ANG_DIST_AR, dtype: float64 14.836068 23.338406
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.454691
# Name: ANG_DIST_AR, dtype: float64 14.836068 23.338406
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.454691
# Name: ANG_DIST_AR, dtype: float64 14.836068 23.338406
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -1.866614
# Name: ANG_DIST_AR, dtype: float64 -11.085312 -62.281403
# 0   -1.901976
# Name: ANG_DIST_AR, dtype: float64 15.289867 -64.699753
# 0   -1.799815
# Name: ANG_DIST_AR, dtype: float64 15.63976 -58.635868
# 0   -1.795863
# Name: ANG_DIST_AR, dtype: float64 15.634167 -58.399887
# 0   -1.720141
# Name: ANG_DIST_AR, dtype: float64 17.453587 -53.973156
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -1.518564
# Name: ANG_DIST_AR, dtype: float64 17.37851 -41.86401
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.901826
# Name: ANG_DIST_AR, dtype: float64 13.680098 -5.335882
# 0   -0.870591
# Name: ANG_DIST_AR, dtype: float64 13.595557 -3.474687
# 0   -0.811101
# Name: ANG_DIST_AR, dtype: float64 13.60854 0.120598
# 0   -0.776596
# Name: ANG_DIST_AR, dtype: float64 13.855698 2.280298
# 0   -0.691347
# Name: ANG_DIST_AR, dtype: float64 13.799118 7.493447
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.497125
# Name: ANG_DIST_AR, dtype: float64 13.110003 19.485857
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.326139
# Name: ANG_DIST_AR, dtype: float64 12.596636 31.084208
# 0   -0.283897
# Name: ANG_DIST_AR, dtype: float64 12.627391 34.661991
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -1.808953
# Name: ANG_DIST_AR, dtype: float64 -23.108227 -59.861973
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -1.496421
# Name: ANG_DIST_AR, dtype: float64 18.44507 -40.507412
# 0   -1.455341
# Name: ANG_DIST_AR, dtype: float64 18.652826 -38.016399
# 0   -1.362521
# Name: ANG_DIST_AR, dtype: float64 18.662413 -32.393822
# 0   -0.944204
# Name: ANG_DIST_AR, dtype: float64 25.091017 -4.647569
# 0   -1.653935
# Name: ANG_DIST_AR, dtype: float64 24.726583 -50.245628
# 0   -0.879433
# Name: ANG_DIST_AR, dtype: float64 25.118246 -0.236689
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.770963
# Name: ANG_DIST_AR, dtype: float64 25.13508 7.397225
# 0   -0.989265
# Name: ANG_DIST_AR, dtype: float64 24.049061 -8.021346
# 0   -0.892376
# Name: ANG_DIST_AR, dtype: float64 23.942713 -1.634601
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.818154
# Name: ANG_DIST_AR, dtype: float64 23.891045 3.385374
# 0   -0.512979
# Name: ANG_DIST_AR, dtype: float64 23.844454 27.287256
# 0   -0.451595
# Name: ANG_DIST_AR, dtype: float64 23.794945 34.527084
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.42792
# Name: ANG_DIST_AR, dtype: float64 23.80567 38.954102
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.418197
# Name: ANG_DIST_AR, dtype: float64 23.857155 42.704586
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.858565
# Name: ANG_DIST_AR, dtype: float64 20.052748 -0.917048
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0    0.428843
# Name: ANG_DIST_AR, dtype: float64 23.762135 51.441933
# 0   -1.341776
# Name: ANG_DIST_AR, dtype: float64 8.200024 -31.740129
# 0   -1.212598
# Name: ANG_DIST_AR, dtype: float64 8.041584 -24.263596
# 0   -1.90382
# Name: ANG_DIST_AR, dtype: float64 9.74443 -64.371269
# 0   -0.478509
# Name: ANG_DIST_AR, dtype: float64 18.750944 24.625483
# 0   -0.443864
# Name: ANG_DIST_AR, dtype: float64 18.851419 27.609001
# 0   -1.301366
# Name: ANG_DIST_AR, dtype: float64 10.273666 -29.304808
# 0   -1.582201
# Name: ANG_DIST_AR, dtype: float64 -23.662142 -45.713413
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.517933
# Name: ANG_DIST_AR, dtype: float64 -22.110086 24.686684
# 0   -0.502914
# Name: ANG_DIST_AR, dtype: float64 -22.12821 26.058397
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -1.533605
# Name: ANG_DIST_AR, dtype: float64 22.398144 -42.695145
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -1.84372
# Name: ANG_DIST_AR, dtype: float64 -18.940052 -61.557484
# 0   -0.54991
# Name: ANG_DIST_AR, dtype: float64 -22.88348 22.729223
# 0   -0.490351
# Name: ANG_DIST_AR, dtype: float64 -23.107176 28.559664
# 0   -0.447798
# Name: ANG_DIST_AR, dtype: float64 -23.157948 33.637142
# 0   -0.420754
# Name: ANG_DIST_AR, dtype: float64 -23.1248 37.992153
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -1.689472
# Name: ANG_DIST_AR, dtype: float64 -21.88747 -52.330616
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0    0.414087
# Name: ANG_DIST_AR, dtype: float64 -23.718012 45.610706
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -1.373692
# Name: ANG_DIST_AR, dtype: float64 -17.471338 -33.152847
# 0   -1.184846
# Name: ANG_DIST_AR, dtype: float64 -18.500854 -21.612055
# 0   -1.082211
# Name: ANG_DIST_AR, dtype: float64 -18.810089 -15.273543
# 0   -0.946738
# Name: ANG_DIST_AR, dtype: float64 -19.026056 -6.822477
# 0   -0.839721
# Name: ANG_DIST_AR, dtype: float64 -19.08803 -0.047805
# 0   -0.731349
# Name: ANG_DIST_AR, dtype: float64 -19.439531 7.117149
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.652755
# Name: ANG_DIST_AR, dtype: float64 -19.488613 12.425596
# 0   -0.560385
# Name: ANG_DIST_AR, dtype: float64 -19.798021 19.192614
# 0   -0.36219
# Name: ANG_DIST_AR, dtype: float64 -20.552258 42.063656
# 0   -0.360274
# Name: ANG_DIST_AR, dtype: float64 -20.561895 43.140411
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -1.895592
# Name: ANG_DIST_AR, dtype: float64 13.572412 -64.164574
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -1.701684
# Name: ANG_DIST_AR, dtype: float64 13.758886 -52.722218
# 0   -1.65203
# Name: ANG_DIST_AR, dtype: float64 13.796447 -49.792931
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -1.858812
# Name: ANG_DIST_AR, dtype: float64 7.994444 -61.66877
# 0   -1.161374
# Name: ANG_DIST_AR, dtype: float64 13.793678 -20.80143
# 0   -1.065339
# Name: ANG_DIST_AR, dtype: float64 13.706706 -15.105688
# 0   -1.052931
# Name: ANG_DIST_AR, dtype: float64 13.699886 -14.367987
# 0   -1.044127
# Name: ANG_DIST_AR, dtype: float64 13.704691 -13.842858
# 0   -0.955197
# Name: ANG_DIST_AR, dtype: float64 13.742666 -8.525445
# 0   -0.925453
# Name: ANG_DIST_AR, dtype: float64 13.742034 -6.742457
# 0   -1.623613
# Name: ANG_DIST_AR, dtype: float64 -7.362918 -48.051369
# 0   -0.898413
# Name: ANG_DIST_AR, dtype: float64 13.739137 -5.11873
# 0   -0.890089
# Name: ANG_DIST_AR, dtype: float64 13.735157 -4.618865
# 0   -0.882348
# Name: ANG_DIST_AR, dtype: float64 13.738608 -4.152133
# 0   -0.863508
# Name: ANG_DIST_AR, dtype: float64 13.723788 -3.020064
# 0   -0.828364
# Name: ANG_DIST_AR, dtype: float64 13.713242 -0.899445
# 0   -0.752112
# Name: ANG_DIST_AR, dtype: float64 13.510613 3.679789
# 0   -0.746229
# Name: ANG_DIST_AR, dtype: float64 13.504107 4.036814
# 0   -0.724924
# Name: ANG_DIST_AR, dtype: float64 13.494625 5.336196
# 0   -0.651216
# Name: ANG_DIST_AR, dtype: float64 13.336171 9.824291
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.563287
# Name: ANG_DIST_AR, dtype: float64 13.274686 15.309769
# 0   -0.741267
# Name: ANG_DIST_AR, dtype: float64 -7.937134 3.137441
# 0   -0.669024
# Name: ANG_DIST_AR, dtype: float64 -7.885637 7.364921
# 0   -0.405067
# Name: ANG_DIST_AR, dtype: float64 13.489763 25.935463
# 0   -0.637881
# Name: ANG_DIST_AR, dtype: float64 -7.905224 9.200291
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0
# 0   -0.785398
# Name: ANG_DIST_AR, dtype: float64 0 0

# %% [markdown]
# Some Final Touches (machine learning ready file)

# %%
# After the loop, convert the master list or array to a DataFrame

combined_df = pd.DataFrame(rows, columns=combined_row.columns)
rows_before = len(combined_df); print('Total number of flares: {}'.format(rows_before))
combined_df = combined_df[combined_df['RSUN_OBS'] != 0] # get rid of the ones that no shmarp information was found
print('-')
print('Flares without SHARP info: {}'.format(rows_before-len(combined_df)))

combined_df['T_OBS'] = pd.to_datetime(combined_df['T_OBS'], format='%m-%d-%Y %H:%M:%S') # Convert 'T_OBS' column to datetime object
combined_df['T_OBS'] = combined_df['T_OBS'].dt.strftime('%Y-%m-%d %H:%M:%S') # Format 'T_OBS' column to match the other date columns
combined_df = combined_df.drop(columns=['DBINDEX','UNIX_TIME', 'NOAA_ARS', 'QUALITY']) #drop some key values (reading reasons)
combined_df['intensity'] = combined_df['intensity'].apply(lambda x: round_to_n(x, 7)) # fix intensity decimal problem (reading reasons)

rows_before = len(combined_df)
combined_df['time_diff'] = (pd.to_datetime(combined_df['T_OBS']) - pd.to_datetime(combined_df['t_start'])).dt.total_seconds() / 60
combined_df = combined_df[combined_df['time_diff'] < 0] # get rid of the ones that are positive
print('-')
print('Flares that the SHMARP information is after emergeance: {}'.format(rows_before-len(combined_df)))

combined_df.to_csv('Flares_SEPs_SHMARPs_t-{}.dat'.format(before_start_time), sep='\t', index=False) # SAVING THE MACHINE LEARNING READY FILE
# Out:
# Total number of flares: 4497
# -
# Flares without SHARP info: 1756
# -
# Flares that the SHMARP information is after emergeance: 0
