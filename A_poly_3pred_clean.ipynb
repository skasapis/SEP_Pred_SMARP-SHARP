# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import svm
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn import preprocessing
from sklearn import metrics
from mpl_toolkits.axes_grid1.inset_locator import inset_axes
from functions import calculate_tss, calculate_hss
import seaborn as sns
import sys
import random

# %% [markdown]
# # Read in Data

# %%
flares = pd.read_csv("Flares_SEPs_SHMARPs_t-2.dat", sep="\t")  # Adjust the 'sep' parameter according to your file's delimiter.
print(flares.columns)
# Out:
# Index(['t_start', 't_max', 't_end', 'class', 'location', 'AR', 'SEP_Match',
#        'intensity', 'coords', 'ang_dist', 'T_OBS', 'ARPNUM', 'NOAA_AR',
#        'CAR_ROT', 'USFLUXL', 'R_VALUE', 'MEANGBL_GMM', 'MEANGBZ', 'USFLUXZ',
#        'CMASKL', 'LAT_FWT', 'CRLT_OBS', 'LON_FWT', 'CRLN_OBS', 'CDELT1',
#        'DSUN_OBS', 'RSUN_OBS', 'ANG_DIST_AR', 'time_diff'],
#       dtype='object')

# %% [markdown]
# # Check Some Stats

# %%
# Separate the DataFrame into positive and negative datasets
positive_flares = flares[flares['SEP_Match'] == True]
negative_flares = flares[flares['SEP_Match'] == False]

# Filter out rows with 'time_diff' less than -3000 for positive flares
positive_flares = positive_flares[positive_flares['time_diff'] >= -3000]
negative_flares = negative_flares[negative_flares['time_diff'] >= -3000]

# %% [markdown]
# ## Remove SEP-Causing ARs from Negative List (optional)

# %%
remove_active = True
if remove_active == True:
    sep_ars = set(positive_flares['AR'])
    print(len(negative_flares))
    negative_flares = negative_flares[~negative_flares['AR'].isin(sep_ars)]
    print(len(negative_flares), negative_flares)
# Out:
# 3224
# 2578                   t_start                t_max                t_end class  \
# 0     1996-07-09 01:38:00  1996-07-09 01:44:00  1996-07-09 02:05:00  M1.4
# 1     1996-07-09 09:05:00  1996-07-09 09:11:00  1996-07-09 09:15:00  X2.6
# 2     1996-07-10 02:49:00  1996-07-10 03:43:00  1996-07-10 04:02:00  M1.0
# 3     1996-11-29 20:16:00  1996-11-29 20:44:00  1996-11-29 20:55:00  M1.0
# 4     1996-11-30 20:32:00  1996-11-30 21:03:00  1996-11-30 21:30:00  C8.6
# ...                   ...                  ...                  ...   ...
# 3373  2023-05-05 06:52:00  2023-05-05 07:06:00  2023-05-05 07:16:00  C9.5
# 3376  2023-05-06 00:11:00  2023-05-06 00:31:00  2023-05-06 00:36:00  C2.3
# 3377  2023-05-06 17:38:00  2023-05-06 17:45:00  2023-05-06 17:52:00  C1.8
# 3384  2023-05-09 00:05:00  2023-05-09 00:33:00  2023-05-09 00:57:00  C2.7
# 3395  2023-05-11 01:02:00  2023-05-11 01:09:00  2023-05-11 01:17:00  C4.1
#
#      location     AR  SEP_Match  intensity     coords  ang_dist  ...  \
# 0      S10W28   7978      False   0.000014  (-10, 28) -0.342922  ...
# 1      S10W30   7978      False   0.000260  (-10, 30) -0.313528  ...
# 2      S11W39   7978      False   0.000010  (-11, 39) -0.218380  ...
# 3      S06W47   7999      False   0.000010   (-6, 47)  0.110364  ...
# 4      S05W63   7999      False   0.000009   (-5, 63)  0.325667  ...
# ...       ...    ...        ...        ...        ...       ...  ...
# 3373   N08E46  13297      False   0.000010   (8, -46) -1.588080  ...
# 3376   N10E40  13297      False   0.000002  (10, -40) -1.484859  ...
# 3377   N09E25  13297      False   0.000002   (9, -25) -1.226208  ...
# 3384   S07E15  13299      False   0.000003  (-7, -15) -1.051496  ...
# 3395   S07W34  13294      False   0.000004   (-7, 34) -0.227158  ...
#
#              CMASKL    LAT_FWT  CRLT_OBS    LON_FWT    CRLN_OBS  CDELT1  \
# 0     119086.520783 -10.650000  3.740000  23.290000  224.650000    0.12
# 1     121549.050930 -10.750000  3.780000  27.750000  220.240000    0.12
# 2     126122.321203 -10.880000  3.850000  37.580000  210.540000    0.12
# 3     160017.289723  -4.250000  0.960000  45.120000  125.710000    0.12
# 4     145576.309362  -4.250000  0.830000  58.770000  112.540000    0.12
# ...             ...        ...       ...        ...         ...     ...
# 3373  134678.000000   8.033103 -3.783799 -48.554905  167.811234    0.03
# 3376  139830.000000   7.970693 -3.725718 -39.044476  158.338470    0.03
# 3377  149302.000000   7.916721 -3.644642 -29.218021  148.667221    0.03
# 3384   92329.000000  -7.518939 -3.405617 -16.815218  118.676376    0.03
# 3395   52040.000000  -7.905224 -3.392118   9.200291  117.569489    0.03
#
#           DSUN_OBS    RSUN_OBS  ANG_DIST_AR    time_diff
# 0     1.505115e+11  953.819775    -0.420060  -189.500000
# 1     1.505128e+11  953.811202    -0.353231  -156.500000
# 2     1.505156e+11  953.793764    -0.229407  -164.500000
# 3     1.459020e+11  983.953786     0.074206  -156.500000
# 4     1.458748e+11  984.137131     0.251307  -172.500000
# ...            ...         ...          ...          ...
# 3373  1.508707e+11  951.548523    -1.632231  -123.933333
# 3376  1.508494e+11  951.683044    -1.467860  -130.933333
# 3377  1.508841e+11  951.464294    -1.298041  -121.933333
# 3384  1.509582e+11  950.997375    -1.083481  -124.916667
# 3395  1.509737e+11  950.899353    -0.637881 -2941.916667
#
# [2578 rows x 29 columns]

# %% [markdown]
# # Find Optimal Parameters (Grid Search)

# %%
TN_all = []; FP_all = []; FN_all = []; TP_all = []
accuracy_all = []; cm_all = []

# Combine all data and normalize
predictors = ['USFLUXZ', 'USFLUXL', 'R_VALUE', 'ANG_DIST_AR'] # USFLUXL, R_VALUE,	MEANGBL_GMM, MEANGBZ, USFLUXZ, 'MEANGBZ',
all_data = pd.concat([positive_flares[predictors], negative_flares[predictors]], ignore_index=True) # Combine positive and negative datasets
all_data = all_data.dropna()
scaler = preprocessing.StandardScaler().fit(all_data) # Scale all the data
all_data_scaled = scaler.transform(all_data)

# Now, split back into positive and negative datasets
idxs = np.random.choice(len(negative_flares) - len(positive_flares), size=len(positive_flares), replace=False)
positive_data = all_data_scaled[:len(positive_flares)] 
negative_data = (all_data_scaled[len(positive_flares):])[idxs]

# Now split the positive and negative data into training and validation sets
positive_train, positive_val = train_test_split(positive_data, test_size=0.1, random_state=3)
negative_train, negative_val = train_test_split(negative_data, test_size=0.1, random_state=3)

# Ensure that there are equal number of positive and negative instances in validation set
if len(positive_val) < len(negative_val): negative_val = negative_val[:len(positive_val)]; print('Problem')
elif len(negative_val) < len(positive_val): positive_val = positive_val[:len(negative_val)]; print('Problem')
# Combine back the training and validation datasets
X_train = np.vstack((positive_train, negative_train))
Y_train = np.array([1]*len(positive_train) + [0]*len(negative_train))
X_val = np.vstack((positive_val, negative_val))
Y_val = np.array([1]*len(positive_val) + [0]*len(negative_val))

param_grid = {'C': np.logspace(-3, 3, num=10),  # Values like 0.001, 0.01, 0.1, 1, 10, 100, 1000
              'gamma': np.logspace(-3, 1, num=10),  # Values like 0.001, 0.01, 0.1, 1, 10
              'kernel': ['poly'], #['linear', 'rbf', 'sigmoid'],
              'class_weight': ['balanced'],
              'degree': [1, 2, 3]}

grid = GridSearchCV(svm.SVC(), param_grid, refit = True, verbose = 3, n_jobs = -1, cv=2)
grid.fit(X_train, Y_train)
params = grid.best_params_
print(params)
# pd.DataFrame(grid.cv_results_).to_csv("./search.csv")
# output_pred = grid.predict(X_val)
# print(output_pred)
# print(Y_val)
# break
# Out:
# Fitting 2 folds for each of 300 candidates, totalling 600 fits
# [CV 1/2] END C=0.001, class_weight=balanced, degree=1, gamma=0.001, kernel=poly;, score=0.480 total time=   0.0s
# [CV 2/2] END C=0.001, class_weight=balanced, degree=1, gamma=0.001, kernel=poly;, score=0.520 total time=   0.0s
# [CV 2/2] END C=0.001, class_weight=balanced, degree=1, gamma=0.0027825594022071257, kernel=poly;, score=0.520 total time=   0.0s
# [CV 2/2] END C=0.001, class_weight=balanced, degree=1, gamma=0.007742636826811269, kernel=poly;, score=0.520 total time=   0.0s
# [CV 1/2] END C=0.001, class_weight=balanced, degree=1, gamma=0.021544346900318832, kernel=poly;, score=0.480 total time=   0.0s
# [CV 2/2] END C=0.001, class_weight=balanced, degree=1, gamma=0.021544346900318832, kernel=poly;, score=0.520 total time=   0.0s
# [CV 1/2] END C=0.001, class_weight=balanced, degree=1, gamma=0.0027825594022071257, kernel=poly;, score=0.480 total time=   0.0s
# [CV 2/2] END C=0.001, class_weight=balanced, degree=1, gamma=0.05994842503189409, kernel=poly;, score=0.520 total time=   0.0s
# [CV 1/2] END C=0.001, class_weight=balanced, degree=1, gamma=0.05994842503189409, kernel=poly;, score=0.480 total time=   0.0s
# [CV 1/2] END C=0.001, class_weight=balanced, degree=1, gamma=0.1668100537200059, kernel=poly;, score=0.480 total time=   0.0s
# [CV 1/2] END C=0.001, class_weight=balanced, degree=1, gamma=0.007742636826811269, kernel=poly;, score=0.480 total time=   0.0s
# [CV 2/2] END C=0.001, class_weight=balanced, degree=1, gamma=0.1668100537200059, kernel=poly;, score=0.520 total time=   0.0s
# [CV 1/2] END C=0.001, class_weight=balanced, degree=1, gamma=0.46415888336127775, kernel=poly;, score=0.480 total time=   0.0s
# [CV 2/2] END C=0.001, class_weight=balanced, degree=1, gamma=0.46415888336127775, kernel=poly;, score=0.520 total time=   0.0s
# [CV 1/2] END C=0.001, class_weight=balanced, degree=1, gamma=1.2915496650148828, kernel=poly;, score=0.480 total time=   0.0s
# [CV 2/2] END C=0.001, class_weight=balanced, degree=1, gamma=1.2915496650148828, kernel=poly;, score=0.520 total time=   0.0s
# [CV 1/2] END C=0.001, class_weight=balanced, degree=1, gamma=3.593813663804626, kernel=poly;, score=0.480 total time=   0.0s
# [CV 1/2] END C=0.001, class_weight=balanced, degree=2, gamma=0.001, kernel=poly;, score=0.510 total time=   0.0s
# [CV 1/2] END C=0.001, class_weight=balanced, degree=1, gamma=10.0, kernel=poly;, score=0.551 total time=   0.0s
# [CV 1/2] END C=0.001, class_weight=balanced, degree=2, gamma=0.0027825594022071257, kernel=poly;, score=0.510 total time=   0.0s
# [CV 2/2] END C=0.001, class_weight=balanced, degree=1, gamma=3.593813663804626, kernel=poly;, score=0.520 total time=   0.0s
# [CV 2/2] END C=0.001, class_weight=balanced, degree=2, gamma=0.001, kernel=poly;, score=0.510 total time=   0.0s
# [CV 2/2] END C=0.001, class_weight=balanced, degree=1, gamma=10.0, kernel=poly;, score=0.531 total time=   0.0s
# [CV 2/2] END C=0.001, class_weight=balanced, degree=2, gamma=0.0027825594022071257, kernel=poly;, score=0.510 total time=   0.0s
# [CV 1/2] END C=0.001, class_weight=balanced, degree=2, gamma=0.021544346900318832, kernel=poly;, score=0.510 total time=   0.0s
# [CV 1/2] END C=0.001, class_weight=balanced, degree=2, gamma=0.007742636826811269, kernel=poly;, score=0.510 total time=   0.0s
# [CV 1/2] END C=0.001, class_weight=balanced, degree=2, gamma=0.05994842503189409, kernel=poly;, score=0.510 total time=   0.0s
# [CV 2/2] END C=0.001, class_weight=balanced, degree=2, gamma=0.007742636826811269, kernel=poly;, score=0.510 total time=   0.0s
# [CV 2/2] END C=0.001, class_weight=balanced, degree=2, gamma=0.021544346900318832, kernel=poly;, score=0.510 total time=   0.0s
# [CV 2/2] END C=0.001, class_weight=balanced, degree=2, gamma=0.05994842503189409, kernel=poly;, score=0.510 total time=   0.0s
# [CV 1/2] END C=0.001, class_weight=balanced, degree=2, gamma=0.46415888336127775, kernel=poly;, score=0.510 total time=   0.0s
# [CV 1/2] END C=0.001, class_weight=balanced, degree=2, gamma=0.1668100537200059, kernel=poly;, score=0.510 total time=   0.0s
# [CV 2/2] END C=0.001, class_weight=balanced, degree=2, gamma=0.46415888336127775, kernel=poly;, score=0.510 total time=   0.0s
# [CV 2/2] END C=0.001, class_weight=balanced, degree=2, gamma=0.1668100537200059, kernel=poly;, score=0.510 total time=   0.0s
# [CV 1/2] END C=0.001, class_weight=balanced, degree=2, gamma=1.2915496650148828, kernel=poly;, score=0.510 total time=   0.0s
# [CV 2/2] END C=0.001, class_weight=balanced, degree=2, gamma=1.2915496650148828, kernel=poly;, score=0.510 total time=   0.0s
# [CV 1/2] END C=0.001, class_weight=balanced, degree=2, gamma=3.593813663804626, kernel=poly;, score=0.500 total time=   0.0s
# [CV 1/2] END C=0.001, class_weight=balanced, degree=2, gamma=10.0, kernel=poly;, score=0.520 total time=   0.0s
# [CV 2/2] END C=0.001, class_weight=balanced, degree=2, gamma=3.593813663804626, kernel=poly;, score=0.500 total time=   0.0s
# [CV 1/2] END C=0.001, class_weight=balanced, degree=3, gamma=0.001, kernel=poly;, score=0.510 total time=   0.0s
# [CV 2/2] END C=0.001, class_weight=balanced, degree=2, gamma=10.0, kernel=poly;, score=0.490 total time=   0.0s
# [CV 2/2] END C=0.001, class_weight=balanced, degree=3, gamma=0.001, kernel=poly;, score=0.510 total time=   0.0s
# [CV 1/2] END C=0.001, class_weight=balanced, degree=3, gamma=0.007742636826811269, kernel=poly;, score=0.510 total time=   0.0s
# [CV 1/2] END C=0.001, class_weight=balanced, degree=3, gamma=0.0027825594022071257, kernel=poly;, score=0.510 total time=   0.0s
# [CV 1/2] END C=0.001, class_weight=balanced, degree=3, gamma=0.021544346900318832, kernel=poly;, score=0.510 total time=   0.0s[CV 2/2] END C=0.001, class_weight=balanced, degree=3, gamma=0.007742636826811269, kernel=poly;, score=0.510 total time=   0.0s
#
# [CV 2/2] END C=0.001, class_weight=balanced, degree=3, gamma=0.0027825594022071257, kernel=poly;, score=0.510 total time=   0.0s
# [CV 2/2] END C=0.001, class_weight=balanced, degree=3, gamma=0.021544346900318832, kernel=poly;, score=0.510 total time=   0.0s
# [CV 1/2] END C=0.001, class_weight=balanced, degree=3, gamma=0.05994842503189409, kernel=poly;, score=0.510 total time=   0.0s
# [CV 1/2] END C=0.001, class_weight=balanced, degree=3, gamma=0.46415888336127775, kernel=poly;, score=0.510 total time=   0.0s
# [CV 2/2] END C=0.001, class_weight=balanced, degree=3, gamma=0.05994842503189409, kernel=poly;, score=0.510 total time=   0.0s
# [CV 2/2] END C=0.001, class_weight=balanced, degree=3, gamma=0.46415888336127775, kernel=poly;, score=0.510 total time=   0.0s
# [CV 1/2] END C=0.001, class_weight=balanced, degree=3, gamma=0.1668100537200059, kernel=poly;, score=0.510 total time=   0.0s
# [CV 1/2] END C=0.001, class_weight=balanced, degree=3, gamma=3.593813663804626, kernel=poly;, score=0.500 total time=   0.0s
# [CV 2/2] END C=0.001, class_weight=balanced, degree=3, gamma=0.1668100537200059, kernel=poly;, score=0.510 total time=   0.0s
# [CV 1/2] END C=0.001, class_weight=balanced, degree=3, gamma=1.2915496650148828, kernel=poly;, score=0.480 total time=   0.0s
# [CV 1/2] END C=0.004641588833612777, class_weight=balanced, degree=1, gamma=0.007742636826811269, kernel=poly;, score=0.480 total time=   0.0s
# [CV 1/2] END C=0.004641588833612777, class_weight=balanced, degree=1, gamma=0.001, kernel=poly;, score=0.480 total time=   0.0s
# [CV 2/2] END C=0.001, class_weight=balanced, degree=3, gamma=1.2915496650148828, kernel=poly;, score=0.500 total time=   0.0s
# [CV 2/2] END C=0.001, class_weight=balanced, degree=3, gamma=3.593813663804626, kernel=poly;, score=0.510 total time=   0.0s
# [CV 2/2] END C=0.004641588833612777, class_weight=balanced, degree=1, gamma=0.007742636826811269, kernel=poly;, score=0.520 total time=   0.0s
# [CV 2/2] END C=0.004641588833612777, class_weight=balanced, degree=1, gamma=0.001, kernel=poly;, score=0.520 total time=   0.0s
# [CV 1/2] END C=0.004641588833612777, class_weight=balanced, degree=1, gamma=0.05994842503189409, kernel=poly;, score=0.480 total time=   0.0s
# [CV 1/2] END C=0.004641588833612777, class_weight=balanced, degree=1, gamma=0.021544346900318832, kernel=poly;, score=0.480 total time=   0.0s
# [CV 1/2] END C=0.004641588833612777, class_weight=balanced, degree=1, gamma=0.0027825594022071257, kernel=poly;, score=0.480 total time=   0.0s
# [CV 2/2] END C=0.004641588833612777, class_weight=balanced, degree=1, gamma=0.05994842503189409, kernel=poly;, score=0.520 total time=   0.0s
# [CV 2/2] END C=0.004641588833612777, class_weight=balanced, degree=1, gamma=0.021544346900318832, kernel=poly;, score=0.520 total time=   0.0s
# [CV 2/2] END C=0.004641588833612777, class_weight=balanced, degree=1, gamma=0.0027825594022071257, kernel=poly;, score=0.520 total time=   0.0s
# [CV 1/2] END C=0.004641588833612777, class_weight=balanced, degree=1, gamma=0.1668100537200059, kernel=poly;, score=0.480 total time=   0.0s
# [CV 1/2] END C=0.004641588833612777, class_weight=balanced, degree=1, gamma=0.46415888336127775, kernel=poly;, score=0.480 total time=   0.0s
# [CV 1/2] END C=0.001, class_weight=balanced, degree=3, gamma=10.0, kernel=poly;, score=0.510 total time=   0.0s
# [CV 2/2] END C=0.004641588833612777, class_weight=balanced, degree=1, gamma=0.1668100537200059, kernel=poly;, score=0.520 total time=   0.0s
# [CV 2/2] END C=0.004641588833612777, class_weight=balanced, degree=1, gamma=0.46415888336127775, kernel=poly;, score=0.520 total time=   0.0s
# [CV 1/2] END C=0.004641588833612777, class_weight=balanced, degree=2, gamma=0.001, kernel=poly;, score=0.510 total time=   0.0s
# [CV 1/2] END C=0.004641588833612777, class_weight=balanced, degree=1, gamma=1.2915496650148828, kernel=poly;, score=0.480 total time=   0.0s
# [CV 2/2] END C=0.001, class_weight=balanced, degree=3, gamma=10.0, kernel=poly;, score=0.541 total time=   0.0s
# [CV 2/2] END C=0.004641588833612777, class_weight=balanced, degree=2, gamma=0.001, kernel=poly;, score=0.510 total time=   0.0s
# [CV 2/2] END C=0.004641588833612777, class_weight=balanced, degree=1, gamma=1.2915496650148828, kernel=poly;, score=0.520 total time=   0.0s
# [CV 1/2] END C=0.004641588833612777, class_weight=balanced, degree=2, gamma=0.007742636826811269, kernel=poly;, score=0.510 total time=   0.0s
# [CV 1/2] END C=0.004641588833612777, class_weight=balanced, degree=2, gamma=0.0027825594022071257, kernel=poly;, score=0.510 total time=   0.0s
# [CV 1/2] END C=0.004641588833612777, class_weight=balanced, degree=2, gamma=0.05994842503189409, kernel=poly;, score=0.510 total time=   0.0s
# [CV 2/2] END C=0.004641588833612777, class_weight=balanced, degree=2, gamma=0.007742636826811269, kernel=poly;, score=0.510 total time=   0.0s
# [CV 2/2] END C=0.004641588833612777, class_weight=balanced, degree=2, gamma=0.0027825594022071257, kernel=poly;, score=0.510 total time=   0.0s
# [CV 2/2] END C=0.004641588833612777, class_weight=balanced, degree=2, gamma=0.05994842503189409, kernel=poly;, score=0.510 total time=   0.0s
# [CV 1/2] END C=0.004641588833612777, class_weight=balanced, degree=2, gamma=0.021544346900318832, kernel=poly;, score=0.510 total time=   0.0s
# [CV 1/2] END C=0.004641588833612777, class_weight=balanced, degree=2, gamma=0.1668100537200059, kernel=poly;, score=0.510 total time=   0.0s
# [CV 2/2] END C=0.004641588833612777, class_weight=balanced, degree=2, gamma=0.1668100537200059, kernel=poly;, score=0.510 total time=   0.0s
# [CV 1/2] END C=0.004641588833612777, class_weight=balanced, degree=1, gamma=3.593813663804626, kernel=poly;, score=0.612 total time=   0.0s
# [CV 2/2] END C=0.004641588833612777, class_weight=balanced, degree=2, gamma=0.021544346900318832, kernel=poly;, score=0.510 total time=   0.0s[CV 1/2] END C=0.004641588833612777, class_weight=balanced, degree=2, gamma=3.593813663804626, kernel=poly;, score=0.520 total time=   0.0s
#
# [CV 1/2] END C=0.004641588833612777, class_weight=balanced, degree=3, gamma=0.001, kernel=poly;, score=0.510 total time=   0.0s
# [CV 2/2] END C=0.004641588833612777, class_weight=balanced, degree=1, gamma=3.593813663804626, kernel=poly;, score=0.531 total time=   0.0s
# [CV 2/2] END C=0.004641588833612777, class_weight=balanced, degree=2, gamma=3.593813663804626, kernel=poly;, score=0.510 total time=   0.0s
# [CV 2/2] END C=0.004641588833612777, class_weight=balanced, degree=3, gamma=0.001, kernel=poly;, score=0.510 total time=   0.0s
# [CV 1/2] END C=0.004641588833612777, class_weight=balanced, degree=1, gamma=10.0, kernel=poly;, score=0.633 total time=   0.0s
# [CV 1/2] END C=0.004641588833612777, class_weight=balanced, degree=3, gamma=0.0027825594022071257, kernel=poly;, score=0.510 total time=   0.0s
# [CV 2/2] END C=0.004641588833612777, class_weight=balanced, degree=1, gamma=10.0, kernel=poly;, score=0.592 total time=   0.0s
# [CV 1/2] END C=0.004641588833612777, class_weight=balanced, degree=2, gamma=10.0, kernel=poly;, score=0.520 total time=   0.0s
# [CV 2/2] END C=0.004641588833612777, class_weight=balanced, degree=2, gamma=10.0, kernel=poly;, score=0.510 total time=   0.0s
# [CV 1/2] END C=0.004641588833612777, class_weight=balanced, degree=2, gamma=0.46415888336127775, kernel=poly;, score=0.510 total time=   0.0s
# [CV 1/2] END C=0.004641588833612777, class_weight=balanced, degree=3, gamma=0.05994842503189409, kernel=poly;, score=0.510 total time=   0.0s
# [CV 2/2] END C=0.004641588833612777, class_weight=balanced, degree=3, gamma=0.0027825594022071257, kernel=poly;, score=0.510 total time=   0.0s
# [CV 1/2] END C=0.004641588833612777, class_weight=balanced, degree=3, gamma=0.007742636826811269, kernel=poly;, score=0.510 total time=   0.0s
# [CV 2/2] END C=0.004641588833612777, class_weight=balanced, degree=3, gamma=0.05994842503189409, kernel=poly;, score=0.510 total time=   0.0s
# [CV 2/2] END C=0.004641588833612777, class_weight=balanced, degree=2, gamma=0.46415888336127775, kernel=poly;, score=0.510 total time=   0.0s
# [CV 1/2] END C=0.004641588833612777, class_weight=balanced, degree=3, gamma=0.1668100537200059, kernel=poly;, score=0.510 total time=   0.0s
# [CV 2/2] END C=0.004641588833612777, class_weight=balanced, degree=3, gamma=0.007742636826811269, kernel=poly;, score=0.510 total time=   0.0s
# [CV 1/2] END C=0.004641588833612777, class_weight=balanced, degree=2, gamma=1.2915496650148828, kernel=poly;, score=0.510 total time=   0.0s
# [CV 2/2] END C=0.004641588833612777, class_weight=balanced, degree=3, gamma=0.1668100537200059, kernel=poly;, score=0.510 total time=   0.0s
# [CV 1/2] END C=0.004641588833612777, class_weight=balanced, degree=3, gamma=0.021544346900318832, kernel=poly;, score=0.510 total time=   0.0s
# [CV 2/2] END C=0.004641588833612777, class_weight=balanced, degree=2, gamma=1.2915496650148828, kernel=poly;, score=0.510 total time=   0.0s
# [CV 2/2] END C=0.004641588833612777, class_weight=balanced, degree=3, gamma=0.021544346900318832, kernel=poly;, score=0.510 total time=   0.0s
# [CV 1/2] END C=0.004641588833612777, class_weight=balanced, degree=3, gamma=0.46415888336127775, kernel=poly;, score=0.500 total time=   0.0s
# [CV 1/2] END C=0.021544346900318832, class_weight=balanced, degree=1, gamma=0.001, kernel=poly;, score=0.480 total time=   0.0s
# [CV 1/2] END C=0.021544346900318832, class_weight=balanced, degree=1, gamma=0.05994842503189409, kernel=poly;, score=0.480 total time=   0.0s
# [CV 2/2] END C=0.004641588833612777, class_weight=balanced, degree=3, gamma=0.46415888336127775, kernel=poly;, score=0.510 total time=   0.0s
# [CV 2/2] END C=0.021544346900318832, class_weight=balanced, degree=1, gamma=0.001, kernel=poly;, score=0.520 total time=   0.0s
# [CV 2/2] END C=0.021544346900318832, class_weight=balanced, degree=1, gamma=0.05994842503189409, kernel=poly;, score=0.520 total time=   0.0s
# [CV 1/2] END C=0.021544346900318832, class_weight=balanced, degree=1, gamma=0.0027825594022071257, kernel=poly;, score=0.480 total time=   0.0s
# [CV 1/2] END C=0.004641588833612777, class_weight=balanced, degree=3, gamma=1.2915496650148828, kernel=poly;, score=0.469 total time=   0.0s
# [CV 1/2] END C=0.021544346900318832, class_weight=balanced, degree=1, gamma=3.593813663804626, kernel=poly;, score=0.612 total time=   0.0s
# [CV 1/2] END C=0.021544346900318832, class_weight=balanced, degree=1, gamma=0.1668100537200059, kernel=poly;, score=0.480 total time=   0.0s
# [CV 2/2] END C=0.021544346900318832, class_weight=balanced, degree=1, gamma=0.0027825594022071257, kernel=poly;, score=0.520 total time=   0.0s
# [CV 2/2] END C=0.004641588833612777, class_weight=balanced, degree=3, gamma=1.2915496650148828, kernel=poly;, score=0.480 total time=   0.0s
# [CV 2/2] END C=0.021544346900318832, class_weight=balanced, degree=1, gamma=0.1668100537200059, kernel=poly;, score=0.520 total time=   0.0s
# [CV 2/2] END C=0.021544346900318832, class_weight=balanced, degree=1, gamma=3.593813663804626, kernel=poly;, score=0.602 total time=   0.0s
# [CV 1/2] END C=0.021544346900318832, class_weight=balanced, degree=1, gamma=0.007742636826811269, kernel=poly;, score=0.480 total time=   0.0s
# [CV 1/2] END C=0.021544346900318832, class_weight=balanced, degree=2, gamma=0.007742636826811269, kernel=poly;, score=0.510 total time=   0.0s
# [CV 1/2] END C=0.021544346900318832, class_weight=balanced, degree=1, gamma=0.46415888336127775, kernel=poly;, score=0.551 total time=   0.0s
# [CV 1/2] END C=0.021544346900318832, class_weight=balanced, degree=1, gamma=10.0, kernel=poly;, score=0.602 total time=   0.0s
# [CV 2/2] END C=0.021544346900318832, class_weight=balanced, degree=1, gamma=0.007742636826811269, kernel=poly;, score=0.520 total time=   0.0s
# [CV 1/2] END C=0.004641588833612777, class_weight=balanced, degree=3, gamma=3.593813663804626, kernel=poly;, score=0.541 total time=   0.0s
# [CV 2/2] END C=0.021544346900318832, class_weight=balanced, degree=2, gamma=0.007742636826811269, kernel=poly;, score=0.510 total time=   0.0s
# [CV 2/2] END C=0.021544346900318832, class_weight=balanced, degree=1, gamma=0.46415888336127775, kernel=poly;, score=0.531 total time=   0.0s
# [CV 1/2] END C=0.021544346900318832, class_weight=balanced, degree=1, gamma=0.021544346900318832, kernel=poly;, score=0.480 total time=   0.0s
# [CV 2/2] END C=0.021544346900318832, class_weight=balanced, degree=1, gamma=10.0, kernel=poly;, score=0.612 total time=   0.0s
# [CV 1/2] END C=0.021544346900318832, class_weight=balanced, degree=2, gamma=0.021544346900318832, kernel=poly;, score=0.510 total time=   0.0s
# [CV 2/2] END C=0.004641588833612777, class_weight=balanced, degree=3, gamma=3.593813663804626, kernel=poly;, score=0.531 total time=   0.0s
# [CV 1/2] END C=0.021544346900318832, class_weight=balanced, degree=1, gamma=1.2915496650148828, kernel=poly;, score=0.653 total time=   0.0s
# [CV 2/2] END C=0.021544346900318832, class_weight=balanced, degree=1, gamma=0.021544346900318832, kernel=poly;, score=0.520 total time=   0.0s
# [CV 2/2] END C=0.021544346900318832, class_weight=balanced, degree=2, gamma=0.021544346900318832, kernel=poly;, score=0.510 total time=   0.0s
# [CV 2/2] END C=0.021544346900318832, class_weight=balanced, degree=1, gamma=1.2915496650148828, kernel=poly;, score=0.582 total time=   0.0s
# [CV 1/2] END C=0.021544346900318832, class_weight=balanced, degree=2, gamma=0.001, kernel=poly;, score=0.510 total time=   0.0s
# [CV 1/2] END C=0.021544346900318832, class_weight=balanced, degree=2, gamma=0.05994842503189409, kernel=poly;, score=0.510 total time=   0.0s
# [CV 1/2] END C=0.021544346900318832, class_weight=balanced, degree=2, gamma=0.46415888336127775, kernel=poly;, score=0.520 total time=   0.0s
# [CV 2/2] END C=0.021544346900318832, class_weight=balanced, degree=2, gamma=0.001, kernel=poly;, score=0.510 total time=   0.0s
# [CV 1/2] END C=0.021544346900318832, class_weight=balanced, degree=3, gamma=0.001, kernel=poly;, score=0.510 total time=   0.0s
# [CV 2/2] END C=0.021544346900318832, class_weight=balanced, degree=2, gamma=0.05994842503189409, kernel=poly;, score=0.510 total time=   0.0s
# [CV 2/2] END C=0.021544346900318832, class_weight=balanced, degree=2, gamma=0.46415888336127775, kernel=poly;, score=0.510 total time=   0.0s
# [CV 1/2] END C=0.021544346900318832, class_weight=balanced, degree=2, gamma=0.0027825594022071257, kernel=poly;, score=0.510 total time=   0.0s
# [CV 2/2] END C=0.021544346900318832, class_weight=balanced, degree=3, gamma=0.001, kernel=poly;, score=0.510 total time=   0.0s
# [CV 1/2] END C=0.021544346900318832, class_weight=balanced, degree=2, gamma=0.1668100537200059, kernel=poly;, score=0.510 total time=   0.0s
# [CV 2/2] END C=0.021544346900318832, class_weight=balanced, degree=2, gamma=0.0027825594022071257, kernel=poly;, score=0.510 total time=   0.0s
# [CV 1/2] END C=0.021544346900318832, class_weight=balanced, degree=3, gamma=0.0027825594022071257, kernel=poly;, score=0.510 total time=   0.0s
# [CV 1/2] END C=0.021544346900318832, class_weight=balanced, degree=3, gamma=0.05994842503189409, kernel=poly;, score=0.510 total time=   0.0s
# [CV 2/2] END C=0.021544346900318832, class_weight=balanced, degree=2, gamma=0.1668100537200059, kernel=poly;, score=0.510 total time=   0.0s
# [CV 2/2] END C=0.021544346900318832, class_weight=balanced, degree=3, gamma=0.0027825594022071257, kernel=poly;, score=0.510 total time=   0.0s
# [CV 2/2] END C=0.021544346900318832, class_weight=balanced, degree=3, gamma=0.05994842503189409, kernel=poly;, score=0.510 total time=   0.0s
# [CV 1/2] END C=0.1, class_weight=balanced, degree=1, gamma=0.007742636826811269, kernel=poly;, score=0.480 total time=   0.0s
# [CV 1/2] END C=0.021544346900318832, class_weight=balanced, degree=3, gamma=0.007742636826811269, kernel=poly;, score=0.510 total time=   0.0s
# [CV 1/2] END C=0.021544346900318832, class_weight=balanced, degree=2, gamma=1.2915496650148828, kernel=poly;, score=0.500 total time=   0.0s
# [CV 1/2] END C=0.021544346900318832, class_weight=balanced, degree=3, gamma=0.1668100537200059, kernel=poly;, score=0.510 total time=   0.0s
# [CV 2/2] END C=0.1, class_weight=balanced, degree=1, gamma=0.007742636826811269, kernel=poly;, score=0.520 total time=   0.0s
# [CV 2/2] END C=0.021544346900318832, class_weight=balanced, degree=3, gamma=0.007742636826811269, kernel=poly;, score=0.510 total time=   0.0s
# [CV 2/2] END C=0.021544346900318832, class_weight=balanced, degree=2, gamma=1.2915496650148828, kernel=poly;, score=0.500 total time=   0.0s[CV 2/2] END C=0.021544346900318832, class_weight=balanced, degree=3, gamma=0.1668100537200059, kernel=poly;, score=0.510 total time=   0.0s
#
# [CV 1/2] END C=0.1, class_weight=balanced, degree=1, gamma=0.021544346900318832, kernel=poly;, score=0.480 total time=   0.0s
# [CV 1/2] END C=0.021544346900318832, class_weight=balanced, degree=3, gamma=0.021544346900318832, kernel=poly;, score=0.510 total time=   0.0s
# [CV 1/2] END C=0.021544346900318832, class_weight=balanced, degree=3, gamma=3.593813663804626, kernel=poly;, score=0.510 total time=   0.0s
# [CV 1/2] END C=0.021544346900318832, class_weight=balanced, degree=3, gamma=0.46415888336127775, kernel=poly;, score=0.480 total time=   0.0s
# [CV 2/2] END C=0.1, class_weight=balanced, degree=1, gamma=0.021544346900318832, kernel=poly;, score=0.520 total time=   0.0s
# [CV 2/2] END C=0.021544346900318832, class_weight=balanced, degree=3, gamma=0.021544346900318832, kernel=poly;, score=0.510 total time=   0.0s
# [CV 1/2] END C=0.021544346900318832, class_weight=balanced, degree=2, gamma=3.593813663804626, kernel=poly;, score=0.520 total time=   0.0s
# [CV 1/2] END C=0.1, class_weight=balanced, degree=1, gamma=0.05994842503189409, kernel=poly;, score=0.480 total time=   0.0s
# [CV 2/2] END C=0.021544346900318832, class_weight=balanced, degree=3, gamma=0.46415888336127775, kernel=poly;, score=0.500 total time=   0.0s
# [CV 2/2] END C=0.021544346900318832, class_weight=balanced, degree=3, gamma=3.593813663804626, kernel=poly;, score=0.541 total time=   0.0s
# [CV 2/2] END C=0.021544346900318832, class_weight=balanced, degree=2, gamma=3.593813663804626, kernel=poly;, score=0.500 total time=   0.0s
# [CV 1/2] END C=0.1, class_weight=balanced, degree=1, gamma=0.46415888336127775, kernel=poly;, score=0.633 total time=   0.0s
# [CV 2/2] END C=0.1, class_weight=balanced, degree=1, gamma=0.05994842503189409, kernel=poly;, score=0.520 total time=   0.0s
# [CV 2/2] END C=0.1, class_weight=balanced, degree=1, gamma=0.46415888336127775, kernel=poly;, score=0.592 total time=   0.0s
# [CV 1/2] END C=0.021544346900318832, class_weight=balanced, degree=3, gamma=1.2915496650148828, kernel=poly;, score=0.500 total time=   0.0s
# [CV 1/2] END C=0.004641588833612777, class_weight=balanced, degree=3, gamma=10.0, kernel=poly;, score=0.490 total time=   0.0s
# [CV 1/2] END C=0.1, class_weight=balanced, degree=1, gamma=0.1668100537200059, kernel=poly;, score=0.612 total time=   0.0s
# [CV 1/2] END C=0.1, class_weight=balanced, degree=1, gamma=1.2915496650148828, kernel=poly;, score=0.592 total time=   0.0s
# [CV 2/2] END C=0.021544346900318832, class_weight=balanced, degree=3, gamma=1.2915496650148828, kernel=poly;, score=0.510 total time=   0.0s
# [CV 2/2] END C=0.1, class_weight=balanced, degree=1, gamma=0.1668100537200059, kernel=poly;, score=0.531 total time=   0.0s
# [CV 2/2] END C=0.1, class_weight=balanced, degree=1, gamma=1.2915496650148828, kernel=poly;, score=0.612 total time=   0.0s
# [CV 1/2] END C=0.1, class_weight=balanced, degree=2, gamma=0.001, kernel=poly;, score=0.510 total time=   0.0s
# [CV 1/2] END C=0.1, class_weight=balanced, degree=2, gamma=0.05994842503189409, kernel=poly;, score=0.510 total time=   0.0s
# [CV 1/2] END C=0.1, class_weight=balanced, degree=1, gamma=3.593813663804626, kernel=poly;, score=0.602 total time=   0.0s
# [CV 2/2] END C=0.1, class_weight=balanced, degree=2, gamma=0.001, kernel=poly;, score=0.510 total time=   0.0s
# [CV 2/2] END C=0.1, class_weight=balanced, degree=2, gamma=0.05994842503189409, kernel=poly;, score=0.510 total time=   0.0s
# [CV 2/2] END C=0.1, class_weight=balanced, degree=1, gamma=3.593813663804626, kernel=poly;, score=0.622 total time=   0.0s
# [CV 1/2] END C=0.1, class_weight=balanced, degree=2, gamma=0.0027825594022071257, kernel=poly;, score=0.510 total time=   0.0s
# [CV 1/2] END C=0.1, class_weight=balanced, degree=2, gamma=0.1668100537200059, kernel=poly;, score=0.520 total time=   0.0s
# [CV 1/2] END C=0.1, class_weight=balanced, degree=1, gamma=10.0, kernel=poly;, score=0.602 total time=   0.0s
# [CV 2/2] END C=0.1, class_weight=balanced, degree=2, gamma=0.1668100537200059, kernel=poly;, score=0.510 total time=   0.0s
# [CV 2/2] END C=0.1, class_weight=balanced, degree=2, gamma=0.0027825594022071257, kernel=poly;, score=0.510 total time=   0.0s
# [CV 2/2] END C=0.1, class_weight=balanced, degree=1, gamma=10.0, kernel=poly;, score=0.643 total time=   0.0s
# [CV 1/2] END C=0.021544346900318832, class_weight=balanced, degree=2, gamma=10.0, kernel=poly;, score=0.510 total time=   0.0s
# [CV 1/2] END C=0.1, class_weight=balanced, degree=2, gamma=0.46415888336127775, kernel=poly;, score=0.500 total time=   0.0s
# [CV 2/2] END C=0.004641588833612777, class_weight=balanced, degree=3, gamma=10.0, kernel=poly;, score=0.592 total time=   0.0s
# [CV 1/2] END C=0.1, class_weight=balanced, degree=2, gamma=0.007742636826811269, kernel=poly;, score=0.510 total time=   0.0s
# [CV 2/2] END C=0.1, class_weight=balanced, degree=2, gamma=0.46415888336127775, kernel=poly;, score=0.510 total time=   0.0s
# [CV 1/2] END C=0.1, class_weight=balanced, degree=2, gamma=3.593813663804626, kernel=poly;, score=0.520 total time=   0.0s
# [CV 1/2] END C=0.1, class_weight=balanced, degree=2, gamma=1.2915496650148828, kernel=poly;, score=0.520 total time=   0.0s
# [CV 2/2] END C=0.021544346900318832, class_weight=balanced, degree=2, gamma=10.0, kernel=poly;, score=0.510 total time=   0.0s
# [CV 2/2] END C=0.1, class_weight=balanced, degree=2, gamma=0.007742636826811269, kernel=poly;, score=0.510 total time=   0.0s
# [CV 2/2] END C=0.1, class_weight=balanced, degree=2, gamma=3.593813663804626, kernel=poly;, score=0.541 total time=   0.0s
# [CV 2/2] END C=0.1, class_weight=balanced, degree=2, gamma=1.2915496650148828, kernel=poly;, score=0.500 total time=   0.0s
# [CV 1/2] END C=0.1, class_weight=balanced, degree=2, gamma=0.021544346900318832, kernel=poly;, score=0.510 total time=   0.0s
# [CV 2/2] END C=0.1, class_weight=balanced, degree=2, gamma=0.021544346900318832, kernel=poly;, score=0.510 total time=   0.0s
# [CV 1/2] END C=0.1, class_weight=balanced, degree=3, gamma=0.007742636826811269, kernel=poly;, score=0.510 total time=   0.0s
# [CV 1/2] END C=0.1, class_weight=balanced, degree=3, gamma=0.46415888336127775, kernel=poly;, score=0.469 total time=   0.0s
# [CV 2/2] END C=0.1, class_weight=balanced, degree=3, gamma=0.007742636826811269, kernel=poly;, score=0.510 total time=   0.0s
# [CV 2/2] END C=0.1, class_weight=balanced, degree=3, gamma=0.46415888336127775, kernel=poly;, score=0.480 total time=   0.0s
# [CV 1/2] END C=0.1, class_weight=balanced, degree=3, gamma=0.021544346900318832, kernel=poly;, score=0.510 total time=   0.0s
# [CV 2/2] END C=0.1, class_weight=balanced, degree=3, gamma=0.021544346900318832, kernel=poly;, score=0.510 total time=   0.0s
# [CV 1/2] END C=0.1, class_weight=balanced, degree=3, gamma=1.2915496650148828, kernel=poly;, score=0.541 total time=   0.0s
# [CV 1/2] END C=0.1, class_weight=balanced, degree=3, gamma=0.05994842503189409, kernel=poly;, score=0.510 total time=   0.0s
# [CV 2/2] END C=0.1, class_weight=balanced, degree=3, gamma=1.2915496650148828, kernel=poly;, score=0.531 total time=   0.0s
# [CV 2/2] END C=0.1, class_weight=balanced, degree=3, gamma=0.05994842503189409, kernel=poly;, score=0.510 total time=   0.0s
# [CV 1/2] END C=0.1, class_weight=balanced, degree=3, gamma=0.1668100537200059, kernel=poly;, score=0.500 total time=   0.0s
# [CV 2/2] END C=0.1, class_weight=balanced, degree=3, gamma=0.1668100537200059, kernel=poly;, score=0.510 total time=   0.0s
# [CV 1/2] END C=0.1, class_weight=balanced, degree=2, gamma=10.0, kernel=poly;, score=0.510 total time=   0.0s
# [CV 1/2] END C=0.46415888336127775, class_weight=balanced, degree=1, gamma=0.001, kernel=poly;, score=0.480 total time=   0.0s
# [CV 2/2] END C=0.46415888336127775, class_weight=balanced, degree=1, gamma=0.001, kernel=poly;, score=0.520 total time=   0.0s
# [CV 1/2] END C=0.46415888336127775, class_weight=balanced, degree=1, gamma=0.0027825594022071257, kernel=poly;, score=0.480 total time=   0.0s
# [CV 2/2] END C=0.46415888336127775, class_weight=balanced, degree=1, gamma=0.0027825594022071257, kernel=poly;, score=0.520 total time=   0.0s
# [CV 2/2] END C=0.1, class_weight=balanced, degree=2, gamma=10.0, kernel=poly;, score=0.531 total time=   0.0s
# [CV 1/2] END C=0.46415888336127775, class_weight=balanced, degree=1, gamma=0.007742636826811269, kernel=poly;, score=0.480 total time=   0.0s
# [CV 1/2] END C=0.1, class_weight=balanced, degree=3, gamma=0.001, kernel=poly;, score=0.510 total time=   0.0s
# [CV 2/2] END C=0.46415888336127775, class_weight=balanced, degree=1, gamma=0.007742636826811269, kernel=poly;, score=0.520 total time=   0.0s
# [CV 2/2] END C=0.1, class_weight=balanced, degree=3, gamma=0.001, kernel=poly;, score=0.510 total time=   0.0s
# [CV 1/2] END C=0.46415888336127775, class_weight=balanced, degree=1, gamma=0.021544346900318832, kernel=poly;, score=0.551 total time=   0.0s
# [CV 1/2] END C=0.1, class_weight=balanced, degree=3, gamma=0.0027825594022071257, kernel=poly;, score=0.510 total time=   0.0s
# [CV 1/2] END C=0.46415888336127775, class_weight=balanced, degree=1, gamma=3.593813663804626, kernel=poly;, score=0.602 total time=   0.0s
# [CV 2/2] END C=0.46415888336127775, class_weight=balanced, degree=1, gamma=0.021544346900318832, kernel=poly;, score=0.531 total time=   0.0s
# [CV 2/2] END C=0.1, class_weight=balanced, degree=3, gamma=0.0027825594022071257, kernel=poly;, score=0.510 total time=   0.0s
# [CV 1/2] END C=0.1, class_weight=balanced, degree=3, gamma=3.593813663804626, kernel=poly;, score=0.490 total time=   0.0s
# [CV 2/2] END C=0.46415888336127775, class_weight=balanced, degree=1, gamma=3.593813663804626, kernel=poly;, score=0.653 total time=   0.0s
# [CV 1/2] END C=0.46415888336127775, class_weight=balanced, degree=1, gamma=0.05994842503189409, kernel=poly;, score=0.653 total time=   0.0s
# [CV 1/2] END C=0.46415888336127775, class_weight=balanced, degree=2, gamma=0.46415888336127775, kernel=poly;, score=0.520 total time=   0.0s
# [CV 2/2] END C=0.46415888336127775, class_weight=balanced, degree=1, gamma=0.05994842503189409, kernel=poly;, score=0.582 total time=   0.0s
# [CV 1/2] END C=0.46415888336127775, class_weight=balanced, degree=1, gamma=10.0, kernel=poly;, score=0.602 total time=   0.0s
# [CV 2/2] END C=0.46415888336127775, class_weight=balanced, degree=2, gamma=0.46415888336127775, kernel=poly;, score=0.490 total time=   0.0s
# [CV 1/2] END C=0.46415888336127775, class_weight=balanced, degree=1, gamma=0.1668100537200059, kernel=poly;, score=0.612 total time=   0.0s
# [CV 2/2] END C=0.46415888336127775, class_weight=balanced, degree=1, gamma=0.1668100537200059, kernel=poly;, score=0.602 total time=   0.0s
# [CV 2/2] END C=0.1, class_weight=balanced, degree=3, gamma=3.593813663804626, kernel=poly;, score=0.592 total time=   0.0s
# [CV 1/2] END C=0.46415888336127775, class_weight=balanced, degree=2, gamma=1.2915496650148828, kernel=poly;, score=0.520 total time=   0.0s
# [CV 1/2] END C=0.46415888336127775, class_weight=balanced, degree=1, gamma=0.46415888336127775, kernel=poly;, score=0.602 total time=   0.0s
# [CV 2/2] END C=0.46415888336127775, class_weight=balanced, degree=2, gamma=1.2915496650148828, kernel=poly;, score=0.541 total time=   0.0s
# [CV 2/2] END C=0.46415888336127775, class_weight=balanced, degree=1, gamma=10.0, kernel=poly;, score=0.653 total time=   0.0s
# [CV 1/2] END C=0.46415888336127775, class_weight=balanced, degree=2, gamma=0.001, kernel=poly;, score=0.510 total time=   0.0s
# [CV 2/2] END C=0.46415888336127775, class_weight=balanced, degree=1, gamma=0.46415888336127775, kernel=poly;, score=0.612 total time=   0.0s
# [CV 2/2] END C=0.46415888336127775, class_weight=balanced, degree=2, gamma=0.001, kernel=poly;, score=0.510 total time=   0.0s
# [CV 1/2] END C=0.46415888336127775, class_weight=balanced, degree=2, gamma=0.0027825594022071257, kernel=poly;, score=0.510 total time=   0.0s
# [CV 1/2] END C=0.46415888336127775, class_weight=balanced, degree=1, gamma=1.2915496650148828, kernel=poly;, score=0.602 total time=   0.0s
# [CV 2/2] END C=0.46415888336127775, class_weight=balanced, degree=2, gamma=0.0027825594022071257, kernel=poly;, score=0.510 total time=   0.0s
# [CV 2/2] END C=0.46415888336127775, class_weight=balanced, degree=1, gamma=1.2915496650148828, kernel=poly;, score=0.612 total time=   0.0s
# [CV 1/2] END C=0.46415888336127775, class_weight=balanced, degree=2, gamma=3.593813663804626, kernel=poly;, score=0.510 total time=   0.0s
# [CV 1/2] END C=0.46415888336127775, class_weight=balanced, degree=2, gamma=0.007742636826811269, kernel=poly;, score=0.510 total time=   0.0s
# [CV 2/2] END C=0.46415888336127775, class_weight=balanced, degree=2, gamma=0.007742636826811269, kernel=poly;, score=0.510 total time=   0.0s
# [CV 2/2] END C=0.46415888336127775, class_weight=balanced, degree=2, gamma=3.593813663804626, kernel=poly;, score=0.541 total time=   0.0s
# [CV 1/2] END C=0.46415888336127775, class_weight=balanced, degree=2, gamma=0.021544346900318832, kernel=poly;, score=0.510 total time=   0.0s
# [CV 2/2] END C=0.46415888336127775, class_weight=balanced, degree=2, gamma=0.021544346900318832, kernel=poly;, score=0.510 total time=   0.0s
# [CV 1/2] END C=0.46415888336127775, class_weight=balanced, degree=3, gamma=0.05994842503189409, kernel=poly;, score=0.510 total time=   0.0s
# [CV 2/2] END C=0.46415888336127775, class_weight=balanced, degree=3, gamma=0.05994842503189409, kernel=poly;, score=0.510 total time=   0.0s
# [CV 1/2] END C=0.021544346900318832, class_weight=balanced, degree=3, gamma=10.0, kernel=poly;, score=0.531 total time=   0.0s
# [CV 1/2] END C=0.46415888336127775, class_weight=balanced, degree=3, gamma=0.1668100537200059, kernel=poly;, score=0.480 total time=   0.0s
# [CV 2/2] END C=0.46415888336127775, class_weight=balanced, degree=3, gamma=0.1668100537200059, kernel=poly;, score=0.500 total time=   0.0s
# [CV 1/2] END C=0.46415888336127775, class_weight=balanced, degree=2, gamma=0.05994842503189409, kernel=poly;, score=0.510 total time=   0.0s
# [CV 1/2] END C=0.46415888336127775, class_weight=balanced, degree=3, gamma=0.46415888336127775, kernel=poly;, score=0.500 total time=   0.0s
# [CV 2/2] END C=0.46415888336127775, class_weight=balanced, degree=3, gamma=0.46415888336127775, kernel=poly;, score=0.510 total time=   0.0s
# [CV 1/2] END C=2.154434690031882, class_weight=balanced, degree=1, gamma=0.007742636826811269, kernel=poly;, score=0.612 total time=   0.0s
# [CV 2/2] END C=2.154434690031882, class_weight=balanced, degree=1, gamma=0.007742636826811269, kernel=poly;, score=0.531 total time=   0.0s
# [CV 1/2] END C=2.154434690031882, class_weight=balanced, degree=1, gamma=0.021544346900318832, kernel=poly;, score=0.633 total time=   0.0s
# [CV 1/2] END C=0.46415888336127775, class_weight=balanced, degree=3, gamma=1.2915496650148828, kernel=poly;, score=0.510 total time=   0.0s
# [CV 2/2] END C=2.154434690031882, class_weight=balanced, degree=1, gamma=0.021544346900318832, kernel=poly;, score=0.592 total time=   0.0s
# [CV 1/2] END C=2.154434690031882, class_weight=balanced, degree=1, gamma=0.05994842503189409, kernel=poly;, score=0.592 total time=   0.0s
# [CV 2/2] END C=2.154434690031882, class_weight=balanced, degree=1, gamma=0.05994842503189409, kernel=poly;, score=0.612 total time=   0.0s
# [CV 1/2] END C=2.154434690031882, class_weight=balanced, degree=1, gamma=0.1668100537200059, kernel=poly;, score=0.602 total time=   0.0s
# [CV 2/2] END C=2.154434690031882, class_weight=balanced, degree=1, gamma=0.1668100537200059, kernel=poly;, score=0.622 total time=   0.0s
# [CV 2/2] END C=0.46415888336127775, class_weight=balanced, degree=2, gamma=0.05994842503189409, kernel=poly;, score=0.510 total time=   0.0s
# [CV 1/2] END C=2.154434690031882, class_weight=balanced, degree=1, gamma=0.46415888336127775, kernel=poly;, score=0.602 total time=   0.0s
# [CV 1/2] END C=0.46415888336127775, class_weight=balanced, degree=2, gamma=0.1668100537200059, kernel=poly;, score=0.500 total time=   0.0s
# [CV 2/2] END C=2.154434690031882, class_weight=balanced, degree=1, gamma=0.46415888336127775, kernel=poly;, score=0.643 total time=   0.0s
# [CV 2/2] END C=0.46415888336127775, class_weight=balanced, degree=2, gamma=0.1668100537200059, kernel=poly;, score=0.500 total time=   0.0s
# [CV 1/2] END C=2.154434690031882, class_weight=balanced, degree=1, gamma=1.2915496650148828, kernel=poly;, score=0.602 total time=   0.0s
# [CV 2/2] END C=0.46415888336127775, class_weight=balanced, degree=3, gamma=1.2915496650148828, kernel=poly;, score=0.541 total time=   0.0s
# [CV 2/2] END C=2.154434690031882, class_weight=balanced, degree=1, gamma=1.2915496650148828, kernel=poly;, score=0.653 total time=   0.0s
# [CV 1/2] END C=2.154434690031882, class_weight=balanced, degree=2, gamma=0.001, kernel=poly;, score=0.510 total time=   0.0s
# [CV 1/2] END C=2.154434690031882, class_weight=balanced, degree=1, gamma=3.593813663804626, kernel=poly;, score=0.612 total time=   0.0s
# [CV 2/2] END C=2.154434690031882, class_weight=balanced, degree=2, gamma=0.001, kernel=poly;, score=0.510 total time=   0.0s
# [CV 1/2] END C=2.154434690031882, class_weight=balanced, degree=2, gamma=0.0027825594022071257, kernel=poly;, score=0.510 total time=   0.0s
# [CV 2/2] END C=2.154434690031882, class_weight=balanced, degree=1, gamma=3.593813663804626, kernel=poly;, score=0.653 total time=   0.0s
# [CV 2/2] END C=2.154434690031882, class_weight=balanced, degree=2, gamma=0.0027825594022071257, kernel=poly;, score=0.510 total time=   0.0s
# [CV 1/2] END C=2.154434690031882, class_weight=balanced, degree=1, gamma=10.0, kernel=poly;, score=0.612 total time=   0.0s
# [CV 2/2] END C=2.154434690031882, class_weight=balanced, degree=1, gamma=10.0, kernel=poly;, score=0.643 total time=   0.0s
# [CV 1/2] END C=2.154434690031882, class_weight=balanced, degree=2, gamma=0.007742636826811269, kernel=poly;, score=0.510 total time=   0.0s
# [CV 2/2] END C=2.154434690031882, class_weight=balanced, degree=2, gamma=0.007742636826811269, kernel=poly;, score=0.510 total time=   0.0s
# [CV 1/2] END C=2.154434690031882, class_weight=balanced, degree=2, gamma=0.021544346900318832, kernel=poly;, score=0.510 total time=   0.0s
# [CV 2/2] END C=2.154434690031882, class_weight=balanced, degree=2, gamma=0.021544346900318832, kernel=poly;, score=0.510 total time=   0.0s
# [CV 1/2] END C=2.154434690031882, class_weight=balanced, degree=3, gamma=0.46415888336127775, kernel=poly;, score=0.541 total time=   0.0s
# [CV 1/2] END C=2.154434690031882, class_weight=balanced, degree=2, gamma=0.05994842503189409, kernel=poly;, score=0.510 total time=   0.0s
# [CV 2/2] END C=2.154434690031882, class_weight=balanced, degree=3, gamma=0.46415888336127775, kernel=poly;, score=0.531 total time=   0.0s
# [CV 2/2] END C=2.154434690031882, class_weight=balanced, degree=2, gamma=0.05994842503189409, kernel=poly;, score=0.510 total time=   0.0s
# [CV 1/2] END C=2.154434690031882, class_weight=balanced, degree=2, gamma=0.1668100537200059, kernel=poly;, score=0.520 total time=   0.0s
# [CV 2/2] END C=2.154434690031882, class_weight=balanced, degree=2, gamma=0.1668100537200059, kernel=poly;, score=0.510 total time=   0.0s
# [CV 1/2] END C=2.154434690031882, class_weight=balanced, degree=2, gamma=0.46415888336127775, kernel=poly;, score=0.520 total time=   0.0s
# [CV 2/2] END C=2.154434690031882, class_weight=balanced, degree=2, gamma=0.46415888336127775, kernel=poly;, score=0.510 total time=   0.0s
# [CV 1/2] END C=2.154434690031882, class_weight=balanced, degree=2, gamma=1.2915496650148828, kernel=poly;, score=0.510 total time=   0.0s
# [CV 2/2] END C=2.154434690031882, class_weight=balanced, degree=2, gamma=1.2915496650148828, kernel=poly;, score=0.531 total time=   0.0s
# [CV 1/2] END C=2.154434690031882, class_weight=balanced, degree=3, gamma=1.2915496650148828, kernel=poly;, score=0.490 total time=   0.0s
# [CV 2/2] END C=2.154434690031882, class_weight=balanced, degree=3, gamma=1.2915496650148828, kernel=poly;, score=0.592 total time=   0.0s
# [CV 1/2] END C=2.154434690031882, class_weight=balanced, degree=2, gamma=3.593813663804626, kernel=poly;, score=0.510 total time=   0.0s
# [CV 2/2] END C=2.154434690031882, class_weight=balanced, degree=2, gamma=3.593813663804626, kernel=poly;, score=0.520 total time=   0.0s
# [CV 1/2] END C=10.0, class_weight=balanced, degree=1, gamma=0.05994842503189409, kernel=poly;, score=0.602 total time=   0.0s
# [CV 2/2] END C=10.0, class_weight=balanced, degree=1, gamma=0.05994842503189409, kernel=poly;, score=0.612 total time=   0.0s
# [CV 1/2] END C=10.0, class_weight=balanced, degree=1, gamma=0.1668100537200059, kernel=poly;, score=0.602 total time=   0.0s
# [CV 2/2] END C=10.0, class_weight=balanced, degree=1, gamma=0.1668100537200059, kernel=poly;, score=0.653 total time=   0.0s
# [CV 1/2] END C=10.0, class_weight=balanced, degree=1, gamma=0.46415888336127775, kernel=poly;, score=0.602 total time=   0.0s
# [CV 2/2] END C=10.0, class_weight=balanced, degree=1, gamma=0.46415888336127775, kernel=poly;, score=0.653 total time=   0.0s
# [CV 2/2] END C=0.021544346900318832, class_weight=balanced, degree=3, gamma=10.0, kernel=poly;, score=0.561 total time=   0.1s
# [CV 1/2] END C=0.46415888336127775, class_weight=balanced, degree=3, gamma=3.593813663804626, kernel=poly;, score=0.531 total time=   0.0s
# [CV 1/2] END C=10.0, class_weight=balanced, degree=1, gamma=1.2915496650148828, kernel=poly;, score=0.612 total time=   0.0s
# [CV 1/2] END C=0.1, class_weight=balanced, degree=1, gamma=0.001, kernel=poly;, score=0.480 total time=   0.0s
# [CV 2/2] END C=0.1, class_weight=balanced, degree=1, gamma=0.001, kernel=poly;, score=0.520 total time=   0.0s
# [CV 2/2] END C=10.0, class_weight=balanced, degree=1, gamma=1.2915496650148828, kernel=poly;, score=0.643 total time=   0.0s
# [CV 1/2] END C=0.1, class_weight=balanced, degree=1, gamma=0.0027825594022071257, kernel=poly;, score=0.480 total time=   0.0s
# [CV 2/2] END C=0.1, class_weight=balanced, degree=1, gamma=0.0027825594022071257, kernel=poly;, score=0.520 total time=   0.0s
# [CV 1/2] END C=10.0, class_weight=balanced, degree=1, gamma=3.593813663804626, kernel=poly;, score=0.612 total time=   0.0s
# [CV 2/2] END C=10.0, class_weight=balanced, degree=1, gamma=3.593813663804626, kernel=poly;, score=0.643 total time=   0.0s
# [CV 1/2] END C=10.0, class_weight=balanced, degree=1, gamma=10.0, kernel=poly;, score=0.612 total time=   0.0s
# [CV 2/2] END C=10.0, class_weight=balanced, degree=1, gamma=10.0, kernel=poly;, score=0.643 total time=   0.0s
# [CV 1/2] END C=10.0, class_weight=balanced, degree=2, gamma=0.007742636826811269, kernel=poly;, score=0.510 total time=   0.0s
# [CV 2/2] END C=10.0, class_weight=balanced, degree=2, gamma=0.007742636826811269, kernel=poly;, score=0.510 total time=   0.0s
# [CV 1/2] END C=10.0, class_weight=balanced, degree=2, gamma=0.021544346900318832, kernel=poly;, score=0.520 total time=   0.0s
# [CV 2/2] END C=10.0, class_weight=balanced, degree=2, gamma=0.021544346900318832, kernel=poly;, score=0.510 total time=   0.0s
# [CV 1/2] END C=10.0, class_weight=balanced, degree=2, gamma=0.05994842503189409, kernel=poly;, score=0.500 total time=   0.0s
# [CV 2/2] END C=10.0, class_weight=balanced, degree=2, gamma=0.05994842503189409, kernel=poly;, score=0.500 total time=   0.0s
# [CV 1/2] END C=10.0, class_weight=balanced, degree=2, gamma=0.1668100537200059, kernel=poly;, score=0.520 total time=   0.0s
# [CV 2/2] END C=10.0, class_weight=balanced, degree=2, gamma=0.1668100537200059, kernel=poly;, score=0.500 total time=   0.0s
# [CV 1/2] END C=0.46415888336127775, class_weight=balanced, degree=2, gamma=10.0, kernel=poly;, score=0.510 total time=   0.1s
# [CV 1/2] END C=10.0, class_weight=balanced, degree=3, gamma=0.001, kernel=poly;, score=0.510 total time=   0.0s
# [CV 2/2] END C=10.0, class_weight=balanced, degree=3, gamma=0.001, kernel=poly;, score=0.510 total time=   0.0s
# [CV 1/2] END C=10.0, class_weight=balanced, degree=2, gamma=0.46415888336127775, kernel=poly;, score=0.510 total time=   0.0s
# [CV 1/2] END C=10.0, class_weight=balanced, degree=3, gamma=0.0027825594022071257, kernel=poly;, score=0.510 total time=   0.0s
# [CV 2/2] END C=10.0, class_weight=balanced, degree=2, gamma=0.46415888336127775, kernel=poly;, score=0.510 total time=   0.0s
# [CV 2/2] END C=10.0, class_weight=balanced, degree=3, gamma=0.0027825594022071257, kernel=poly;, score=0.510 total time=   0.0s
# [CV 1/2] END C=10.0, class_weight=balanced, degree=3, gamma=0.007742636826811269, kernel=poly;, score=0.510 total time=   0.0s
# [CV 2/2] END C=10.0, class_weight=balanced, degree=3, gamma=0.007742636826811269, kernel=poly;, score=0.510 total time=   0.0s
# [CV 1/2] END C=10.0, class_weight=balanced, degree=3, gamma=0.021544346900318832, kernel=poly;, score=0.510 total time=   0.0s
# [CV 2/2] END C=0.46415888336127775, class_weight=balanced, degree=2, gamma=10.0, kernel=poly;, score=0.520 total time=   0.0s
# [CV 2/2] END C=10.0, class_weight=balanced, degree=3, gamma=0.021544346900318832, kernel=poly;, score=0.510 total time=   0.0s
# [CV 1/2] END C=10.0, class_weight=balanced, degree=3, gamma=0.05994842503189409, kernel=poly;, score=0.480 total time=   0.0s
# [CV 2/2] END C=10.0, class_weight=balanced, degree=3, gamma=0.05994842503189409, kernel=poly;, score=0.500 total time=   0.0s
# [CV 1/2] END C=10.0, class_weight=balanced, degree=3, gamma=0.1668100537200059, kernel=poly;, score=0.500 total time=   0.0s
# [CV 2/2] END C=10.0, class_weight=balanced, degree=3, gamma=0.1668100537200059, kernel=poly;, score=0.510 total time=   0.0s
# [CV 1/2] END C=10.0, class_weight=balanced, degree=3, gamma=0.46415888336127775, kernel=poly;, score=0.510 total time=   0.0s
# [CV 2/2] END C=10.0, class_weight=balanced, degree=3, gamma=0.46415888336127775, kernel=poly;, score=0.541 total time=   0.0s
# [CV 1/2] END C=10.0, class_weight=balanced, degree=2, gamma=0.001, kernel=poly;, score=0.510 total time=   0.0s
# ...
# [CV 1/2] END C=215.44346900318823, class_weight=balanced, degree=2, gamma=3.593813663804626, kernel=poly;, score=0.510 total time=   0.9s
# [CV 1/2] END C=215.44346900318823, class_weight=balanced, degree=3, gamma=0.001, kernel=poly;, score=0.510 total time=   0.0s
# [CV 2/2] END C=215.44346900318823, class_weight=balanced, degree=3, gamma=0.001, kernel=poly;, score=0.510 total time=   0.0s
# [CV 1/2] END C=215.44346900318823, class_weight=balanced, degree=3, gamma=0.0027825594022071257, kernel=poly;, score=0.510 total time=   0.0s
# [CV 2/2] END C=215.44346900318823, class_weight=balanced, degree=3, gamma=0.0027825594022071257, kernel=poly;, score=0.510 total time=   0.0s
# [CV 1/2] END C=215.44346900318823, class_weight=balanced, degree=3, gamma=0.007742636826811269, kernel=poly;, score=0.510 total time=   0.0s
# [CV 2/2] END C=215.44346900318823, class_weight=balanced, degree=3, gamma=0.007742636826811269, kernel=poly;, score=0.510 total time=   0.0s
# [CV 1/2] END C=215.44346900318823, class_weight=balanced, degree=3, gamma=0.021544346900318832, kernel=poly;, score=0.480 total time=   0.0s
# [CV 2/2] END C=215.44346900318823, class_weight=balanced, degree=3, gamma=0.021544346900318832, kernel=poly;, score=0.500 total time=   0.0s
# [CV 1/2] END C=215.44346900318823, class_weight=balanced, degree=3, gamma=0.05994842503189409, kernel=poly;, score=0.500 total time=   0.0s
# [CV 2/2] END C=215.44346900318823, class_weight=balanced, degree=3, gamma=0.05994842503189409, kernel=poly;, score=0.510 total time=   0.0s
# [CV 1/2] END C=215.44346900318823, class_weight=balanced, degree=3, gamma=0.1668100537200059, kernel=poly;, score=0.510 total time=   0.0s
# [CV 2/2] END C=215.44346900318823, class_weight=balanced, degree=3, gamma=0.1668100537200059, kernel=poly;, score=0.541 total time=   0.0s
# [CV 1/2] END C=215.44346900318823, class_weight=balanced, degree=3, gamma=0.46415888336127775, kernel=poly;, score=0.531 total time=   0.0s
# [CV 2/2] END C=215.44346900318823, class_weight=balanced, degree=3, gamma=0.46415888336127775, kernel=poly;, score=0.561 total time=   0.0s
# [CV 1/2] END C=215.44346900318823, class_weight=balanced, degree=3, gamma=1.2915496650148828, kernel=poly;, score=0.541 total time=   0.6s
# [CV 2/2] END C=0.46415888336127775, class_weight=balanced, degree=3, gamma=10.0, kernel=poly;, score=0.561 total time=   1.1s
# [CV 1/2] END C=2.154434690031882, class_weight=balanced, degree=1, gamma=0.001, kernel=poly;, score=0.480 total time=   0.0s
# [CV 2/2] END C=2.154434690031882, class_weight=balanced, degree=1, gamma=0.001, kernel=poly;, score=0.520 total time=   0.0s
# [CV 1/2] END C=2.154434690031882, class_weight=balanced, degree=1, gamma=0.0027825594022071257, kernel=poly;, score=0.480 total time=   0.0s
# [CV 2/2] END C=2.154434690031882, class_weight=balanced, degree=1, gamma=0.0027825594022071257, kernel=poly;, score=0.520 total time=   0.0s
# [CV 2/2] END C=10.0, class_weight=balanced, degree=3, gamma=3.593813663804626, kernel=poly;, score=0.561 total time=   1.9s
# [CV 1/2] END C=46.41588833612773, class_weight=balanced, degree=2, gamma=10.0, kernel=poly;, score=0.510 total time=   1.8s
# [CV 2/2] END C=46.41588833612773, class_weight=balanced, degree=2, gamma=10.0, kernel=poly;, score=0.520 total time=   0.3s
# [CV 1/2] END C=46.41588833612773, class_weight=balanced, degree=3, gamma=0.001, kernel=poly;, score=0.510 total time=   0.0s
# [CV 2/2] END C=46.41588833612773, class_weight=balanced, degree=3, gamma=0.001, kernel=poly;, score=0.510 total time=   0.0s
# [CV 1/2] END C=46.41588833612773, class_weight=balanced, degree=3, gamma=0.0027825594022071257, kernel=poly;, score=0.510 total time=   0.0s
# [CV 2/2] END C=46.41588833612773, class_weight=balanced, degree=3, gamma=0.0027825594022071257, kernel=poly;, score=0.510 total time=   0.0s
# [CV 2/2] END C=215.44346900318823, class_weight=balanced, degree=3, gamma=1.2915496650148828, kernel=poly;, score=0.561 total time=   1.1s
# [CV 1/2] END C=2.154434690031882, class_weight=balanced, degree=3, gamma=10.0, kernel=poly;, score=0.541 total time=   3.9s
# [CV 1/2] END C=46.41588833612773, class_weight=balanced, degree=3, gamma=3.593813663804626, kernel=poly;, score=0.541 total time=   4.6s
# [CV 2/2] END C=2.154434690031882, class_weight=balanced, degree=3, gamma=10.0, kernel=poly;, score=0.561 total time=   3.2s
# [CV 1/2] END C=10.0, class_weight=balanced, degree=1, gamma=0.001, kernel=poly;, score=0.551 total time=   0.0s
# [CV 2/2] END C=10.0, class_weight=balanced, degree=1, gamma=0.001, kernel=poly;, score=0.531 total time=   0.0s
# [CV 1/2] END C=10.0, class_weight=balanced, degree=1, gamma=0.0027825594022071257, kernel=poly;, score=0.653 total time=   0.0s
# [CV 2/2] END C=10.0, class_weight=balanced, degree=1, gamma=0.0027825594022071257, kernel=poly;, score=0.582 total time=   0.0s
# [CV 1/2] END C=10.0, class_weight=balanced, degree=1, gamma=0.007742636826811269, kernel=poly;, score=0.612 total time=   0.0s
# [CV 2/2] END C=10.0, class_weight=balanced, degree=1, gamma=0.007742636826811269, kernel=poly;, score=0.602 total time=   0.0s
# [CV 1/2] END C=10.0, class_weight=balanced, degree=1, gamma=0.021544346900318832, kernel=poly;, score=0.602 total time=   0.0s
# [CV 2/2] END C=10.0, class_weight=balanced, degree=1, gamma=0.021544346900318832, kernel=poly;, score=0.612 total time=   0.0s
# [CV 2/2] END C=215.44346900318823, class_weight=balanced, degree=2, gamma=10.0, kernel=poly;, score=0.520 total time=   7.4s
# [CV 1/2] END C=1000.0, class_weight=balanced, degree=1, gamma=0.001, kernel=poly;, score=0.602 total time=   0.0s
# [CV 2/2] END C=1000.0, class_weight=balanced, degree=1, gamma=0.001, kernel=poly;, score=0.643 total time=   0.0s
# [CV 1/2] END C=1000.0, class_weight=balanced, degree=1, gamma=0.0027825594022071257, kernel=poly;, score=0.602 total time=   0.0s
# [CV 2/2] END C=1000.0, class_weight=balanced, degree=1, gamma=0.0027825594022071257, kernel=poly;, score=0.653 total time=   0.0s
# [CV 1/2] END C=1000.0, class_weight=balanced, degree=1, gamma=0.007742636826811269, kernel=poly;, score=0.612 total time=   0.0s
# [CV 2/2] END C=1000.0, class_weight=balanced, degree=1, gamma=0.007742636826811269, kernel=poly;, score=0.653 total time=   0.0s
# [CV 1/2] END C=1000.0, class_weight=balanced, degree=1, gamma=0.021544346900318832, kernel=poly;, score=0.612 total time=   0.0s
# [CV 2/2] END C=1000.0, class_weight=balanced, degree=1, gamma=0.021544346900318832, kernel=poly;, score=0.643 total time=   0.0s
# [CV 1/2] END C=1000.0, class_weight=balanced, degree=1, gamma=0.05994842503189409, kernel=poly;, score=0.612 total time=   0.0s
# [CV 2/2] END C=1000.0, class_weight=balanced, degree=1, gamma=0.05994842503189409, kernel=poly;, score=0.643 total time=   0.0s
# [CV 1/2] END C=1000.0, class_weight=balanced, degree=1, gamma=0.1668100537200059, kernel=poly;, score=0.612 total time=   0.0s
# [CV 2/2] END C=1000.0, class_weight=balanced, degree=1, gamma=0.1668100537200059, kernel=poly;, score=0.643 total time=   0.0s
# [CV 1/2] END C=1000.0, class_weight=balanced, degree=1, gamma=0.46415888336127775, kernel=poly;, score=0.612 total time=   0.0s
# [CV 2/2] END C=1000.0, class_weight=balanced, degree=1, gamma=0.46415888336127775, kernel=poly;, score=0.643 total time=   0.0s
# [CV 1/2] END C=1000.0, class_weight=balanced, degree=1, gamma=1.2915496650148828, kernel=poly;, score=0.612 total time=   0.0s
# [CV 2/2] END C=1000.0, class_weight=balanced, degree=1, gamma=1.2915496650148828, kernel=poly;, score=0.643 total time=   0.1s
# [CV 1/2] END C=1000.0, class_weight=balanced, degree=1, gamma=3.593813663804626, kernel=poly;, score=0.612 total time=   0.1s
# [CV 2/2] END C=1000.0, class_weight=balanced, degree=1, gamma=3.593813663804626, kernel=poly;, score=0.643 total time=   0.1s
# [CV 1/2] END C=215.44346900318823, class_weight=balanced, degree=2, gamma=10.0, kernel=poly;, score=0.510 total time=   8.1s
# [CV 1/2] END C=1000.0, class_weight=balanced, degree=1, gamma=10.0, kernel=poly;, score=0.612 total time=   0.3s
# [CV 1/2] END C=1000.0, class_weight=balanced, degree=2, gamma=0.001, kernel=poly;, score=0.510 total time=   0.0s
# [CV 2/2] END C=1000.0, class_weight=balanced, degree=2, gamma=0.001, kernel=poly;, score=0.510 total time=   0.0s
# [CV 1/2] END C=1000.0, class_weight=balanced, degree=2, gamma=0.0027825594022071257, kernel=poly;, score=0.510 total time=   0.0s
# [CV 2/2] END C=1000.0, class_weight=balanced, degree=2, gamma=0.0027825594022071257, kernel=poly;, score=0.510 total time=   0.0s
# [CV 1/2] END C=1000.0, class_weight=balanced, degree=2, gamma=0.007742636826811269, kernel=poly;, score=0.520 total time=   0.0s
# [CV 2/2] END C=1000.0, class_weight=balanced, degree=2, gamma=0.007742636826811269, kernel=poly;, score=0.510 total time=   0.0s
# [CV 1/2] END C=1000.0, class_weight=balanced, degree=2, gamma=0.021544346900318832, kernel=poly;, score=0.520 total time=   0.0s
# [CV 2/2] END C=1000.0, class_weight=balanced, degree=2, gamma=0.021544346900318832, kernel=poly;, score=0.510 total time=   0.0s
# [CV 1/2] END C=1000.0, class_weight=balanced, degree=2, gamma=0.05994842503189409, kernel=poly;, score=0.510 total time=   0.0s
# [CV 2/2] END C=1000.0, class_weight=balanced, degree=2, gamma=0.05994842503189409, kernel=poly;, score=0.531 total time=   0.0s
# [CV 1/2] END C=1000.0, class_weight=balanced, degree=2, gamma=0.1668100537200059, kernel=poly;, score=0.510 total time=   0.0s
# [CV 2/2] END C=1000.0, class_weight=balanced, degree=2, gamma=0.1668100537200059, kernel=poly;, score=0.520 total time=   0.0s
# [CV 1/2] END C=1000.0, class_weight=balanced, degree=2, gamma=0.46415888336127775, kernel=poly;, score=0.510 total time=   0.1s
# [CV 2/2] END C=1000.0, class_weight=balanced, degree=2, gamma=0.46415888336127775, kernel=poly;, score=0.520 total time=   0.0s
# [CV 2/2] END C=1000.0, class_weight=balanced, degree=1, gamma=10.0, kernel=poly;, score=0.643 total time=   0.5s
# [CV 2/2] END C=1000.0, class_weight=balanced, degree=2, gamma=1.2915496650148828, kernel=poly;, score=0.520 total time=   0.2s
# [CV 1/2] END C=1000.0, class_weight=balanced, degree=2, gamma=1.2915496650148828, kernel=poly;, score=0.510 total time=   1.5s
# [CV 2/2] END C=46.41588833612773, class_weight=balanced, degree=3, gamma=3.593813663804626, kernel=poly;, score=0.561 total time=   7.3s
# [CV 2/2] END C=1000.0, class_weight=balanced, degree=2, gamma=3.593813663804626, kernel=poly;, score=0.520 total time=   2.1s
# [CV 1/2] END C=10.0, class_weight=balanced, degree=3, gamma=10.0, kernel=poly;, score=0.551 total time=  12.5s
# [CV 1/2] END C=1000.0, class_weight=balanced, degree=2, gamma=3.593813663804626, kernel=poly;, score=0.490 total time=  12.0s
# [CV 2/2] END C=215.44346900318823, class_weight=balanced, degree=3, gamma=3.593813663804626, kernel=poly;, score=0.561 total time=  23.4s
# [CV 1/2] END C=1000.0, class_weight=balanced, degree=3, gamma=0.001, kernel=poly;, score=0.510 total time=   0.0s
# [CV 2/2] END C=1000.0, class_weight=balanced, degree=3, gamma=0.001, kernel=poly;, score=0.510 total time=   0.0s
# [CV 1/2] END C=1000.0, class_weight=balanced, degree=3, gamma=0.0027825594022071257, kernel=poly;, score=0.510 total time=   0.0s
# [CV 2/2] END C=1000.0, class_weight=balanced, degree=3, gamma=0.0027825594022071257, kernel=poly;, score=0.510 total time=   0.0s
# [CV 1/2] END C=1000.0, class_weight=balanced, degree=3, gamma=0.007742636826811269, kernel=poly;, score=0.500 total time=   0.0s
# [CV 2/2] END C=1000.0, class_weight=balanced, degree=3, gamma=0.007742636826811269, kernel=poly;, score=0.510 total time=   0.0s
# [CV 1/2] END C=1000.0, class_weight=balanced, degree=3, gamma=0.021544346900318832, kernel=poly;, score=0.469 total time=   0.0s
# [CV 2/2] END C=1000.0, class_weight=balanced, degree=3, gamma=0.021544346900318832, kernel=poly;, score=0.480 total time=   0.0s
# [CV 1/2] END C=1000.0, class_weight=balanced, degree=3, gamma=0.05994842503189409, kernel=poly;, score=0.541 total time=   0.0s
# [CV 2/2] END C=1000.0, class_weight=balanced, degree=3, gamma=0.05994842503189409, kernel=poly;, score=0.531 total time=   0.0s
# [CV 1/2] END C=1000.0, class_weight=balanced, degree=3, gamma=0.1668100537200059, kernel=poly;, score=0.490 total time=   0.0s
# [CV 2/2] END C=1000.0, class_weight=balanced, degree=3, gamma=0.1668100537200059, kernel=poly;, score=0.592 total time=   0.0s
# [CV 1/2] END C=1000.0, class_weight=balanced, degree=3, gamma=0.46415888336127775, kernel=poly;, score=0.541 total time=   0.2s
# [CV 2/2] END C=1000.0, class_weight=balanced, degree=3, gamma=0.46415888336127775, kernel=poly;, score=0.561 total time=   0.1s
# [CV 1/2] END C=1000.0, class_weight=balanced, degree=3, gamma=1.2915496650148828, kernel=poly;, score=0.541 total time=   3.6s
# [CV 2/2] END C=1000.0, class_weight=balanced, degree=3, gamma=1.2915496650148828, kernel=poly;, score=0.561 total time=   2.3s
# [CV 2/2] END C=10.0, class_weight=balanced, degree=3, gamma=10.0, kernel=poly;, score=0.561 total time=  19.7s
# [CV 1/2] END C=46.41588833612773, class_weight=balanced, degree=1, gamma=0.001, kernel=poly;, score=0.633 total time=   0.0s
# [CV 2/2] END C=46.41588833612773, class_weight=balanced, degree=1, gamma=0.001, kernel=poly;, score=0.592 total time=   0.0s
# [CV 1/2] END C=46.41588833612773, class_weight=balanced, degree=1, gamma=0.0027825594022071257, kernel=poly;, score=0.592 total time=   0.0s
# [CV 2/2] END C=46.41588833612773, class_weight=balanced, degree=1, gamma=0.0027825594022071257, kernel=poly;, score=0.612 total time=   0.0s
# [CV 1/2] END C=46.41588833612773, class_weight=balanced, degree=1, gamma=0.007742636826811269, kernel=poly;, score=0.602 total time=   0.0s
# [CV 2/2] END C=46.41588833612773, class_weight=balanced, degree=1, gamma=0.007742636826811269, kernel=poly;, score=0.622 total time=   0.0s
# [CV 1/2] END C=46.41588833612773, class_weight=balanced, degree=1, gamma=0.021544346900318832, kernel=poly;, score=0.602 total time=   0.0s
# [CV 2/2] END C=46.41588833612773, class_weight=balanced, degree=1, gamma=0.021544346900318832, kernel=poly;, score=0.643 total time=   0.0s
# [CV 1/2] END C=46.41588833612773, class_weight=balanced, degree=1, gamma=0.05994842503189409, kernel=poly;, score=0.602 total time=   0.0s
# [CV 2/2] END C=46.41588833612773, class_weight=balanced, degree=1, gamma=0.05994842503189409, kernel=poly;, score=0.653 total time=   0.0s
# [CV 1/2] END C=46.41588833612773, class_weight=balanced, degree=1, gamma=0.1668100537200059, kernel=poly;, score=0.612 total time=   0.0s
# [CV 2/2] END C=46.41588833612773, class_weight=balanced, degree=1, gamma=0.1668100537200059, kernel=poly;, score=0.653 total time=   0.0s
# [CV 1/2] END C=46.41588833612773, class_weight=balanced, degree=3, gamma=10.0, kernel=poly;, score=0.582 total time=  25.0s
# [CV 2/2] END C=1000.0, class_weight=balanced, degree=2, gamma=10.0, kernel=poly;, score=0.520 total time=  16.7s
# [CV 1/2] END C=215.44346900318823, class_weight=balanced, degree=3, gamma=3.593813663804626, kernel=poly;, score=0.551 total time=  46.1s
# [CV 2/2] END C=1000.0, class_weight=balanced, degree=3, gamma=3.593813663804626, kernel=poly;, score=0.561 total time=  40.0s
# [CV 1/2] END C=1000.0, class_weight=balanced, degree=2, gamma=10.0, kernel=poly;, score=0.531 total time= 1.1min
# [CV 1/2] END C=1000.0, class_weight=balanced, degree=3, gamma=3.593813663804626, kernel=poly;, score=0.582 total time=  48.6s
# [CV 2/2] END C=46.41588833612773, class_weight=balanced, degree=3, gamma=10.0, kernel=poly;, score=0.561 total time=  48.6s
# [CV 1/2] END C=215.44346900318823, class_weight=balanced, degree=3, gamma=10.0, kernel=poly;, score=0.602 total time= 1.5min
# [CV 2/2] END C=215.44346900318823, class_weight=balanced, degree=3, gamma=10.0, kernel=poly;, score=0.561 total time= 3.4min
# [CV 1/2] END C=1000.0, class_weight=balanced, degree=3, gamma=10.0, kernel=poly;, score=0.571 total time= 4.1min
# [CV 2/2] END C=1000.0, class_weight=balanced, degree=3, gamma=10.0, kernel=poly;, score=0.500 total time= 7.5min
# {'C': 2.154434690031882, 'class_weight': 'balanced', 'degree': 1, 'gamma': 3.593813663804626, 'kernel': 'poly'}

# %% [markdown]
# # Training

# %%
TN_all = []; FP_all = []; FN_all = []; TP_all = []
accuracy_all = []; cm_all = []

# Combine all data and normalize
predictors = ['USFLUXZ', 'R_VALUE', 'ANG_DIST_AR']#, 'MEANGBL_GMM', 'MEANGBZ'] 
all_data = pd.concat([positive_flares[predictors], negative_flares[predictors]], ignore_index=True) # Combine positive and negative datasets
all_data = all_data.dropna()
scaler = preprocessing.StandardScaler().fit(all_data) # Scale all the data
all_data_scaled = scaler.transform(all_data)
# print(all_data)
# all_data_scaled = all_data.to_numpy()
total_runs = 100

for run in range(0,total_runs):
    # Now, split back into positive and negative datasets
    idxs = np.random.choice(len(negative_flares) - len(positive_flares), size=len(positive_flares), replace=False)
    positive_data = all_data_scaled[:len(positive_flares)] 
    negative_data = (all_data_scaled[len(positive_flares):])[idxs]
    # Now split the positive and negative data into training and validation sets
    positive_train, positive_val = train_test_split(positive_data, test_size=0.1, random_state=run)
    negative_train, negative_val = train_test_split(negative_data, test_size=0.1, random_state=run)
    # Ensure that there are equal number of positive and negative instances in validation set
    if len(positive_val) < len(negative_val): negative_val = negative_val[:len(positive_val)]; print('Problem')
    elif len(negative_val) < len(positive_val): positive_val = positive_val[:len(negative_val)]; print('Problem')
    # Combine back the training and validation datasets
    X_train = np.vstack((positive_train, negative_train))
    Y_train = np.array([1]*len(positive_train) + [0]*len(negative_train))
    X_val = np.vstack((positive_val, negative_val))
    Y_val = np.array([1]*len(positive_val) + [0]*len(negative_val))
    # Define SVM parameters (Hyperparameters)
    C = 1 #params['C']
    deg = 1 #params['degree']
    gamma = 10 #params['gamma']
    kernel = 'poly'
    # Create and train the SVM model
    model = svm.SVC(kernel=kernel, gamma=gamma, C=C, degree=deg, class_weight='balanced')
    model.fit(X_train, Y_train) #this is the training
    # VALIDATION !!!!!
    output_pred = model.predict(X_val) # Now you can test the model on the validation set
    # Calculate metrics for this specific run
    cm = metrics.confusion_matrix(Y_val, output_pred) # Calculate confusion matrix
    TN, FP, FN, TP = cm.ravel()
    accuracy = metrics.accuracy_score(Y_val, output_pred) # Calculate accuracy
    TN_all.append(TN); FP_all.append(FP); FN_all.append(FN); TP_all.append(TP)
    accuracy_all.append(accuracy); cm_all.append(cm)

# %% [markdown]
# # Calculate TSS and HSS

# %%
tss_all = []; hss_all = [] # Initialize empty lists to store TSS and HSS for each run
for run in range(total_runs): # Calculate TSS and HSS for each run and store in lists
    tp = cm_all[run][0, 0]; fn = cm_all[run][0, 1]; fp = cm_all[run][1, 0]; tn = cm_all[run][1, 1] # Calculate TP, FN, FP and TN
    tss = calculate_tss(tp, tn, fp, fn); hss = calculate_hss(tp, tn, fp, fn) # Calculate TSS and HSS
    tss_all.append(tss); hss_all.append(hss) # Append

# %% [markdown]
# # Plot and Print Results

# %%
# Calculate average confusion matrix
average_cm = np.array([[np.mean(TN_all), np.mean(FP_all)], [np.mean(FN_all), np.mean(TP_all)]])
labels = ['Negative', 'Positive'] # Define labels
average_cm_df = pd.DataFrame(average_cm, index=labels, columns=labels) # Create DataFrame for average confusion matrix

# Calculate cumulative confusion matrix
cumulative_cm = np.array([[int(sum(TN_all)), int(sum(FP_all))], [int(sum(FN_all)), int(sum(TP_all))]])
cumulative_cm_df = pd.DataFrame(cumulative_cm, index=labels, columns=labels) # Create DataFrame for cumulative confusion matrix

# Create a figure with 1 row and 2 columns of subplots
fig, axes = plt.subplots(1, 2, figsize=(8, 3.5))
# Plot average confusion matrix
sns.heatmap(average_cm_df, annot=True, annot_kws={"size": 16}, fmt=".1f", cmap='Blues', cbar=True, linewidths=0.3, ax=axes[0])
axes[0].set_title('Average Confusion Matrix'); axes[0].set_xlabel('Predicted'); axes[0].set_ylabel('Actual')
# Plot cumulative confusion matrix
sns.heatmap(cumulative_cm_df, annot=True, annot_kws={"size": 16}, fmt=".1f", cmap='Blues', cbar=True, linewidths=0.3, ax=axes[1])
axes[1].set_title('Cumulative Confusion Matrix'); axes[1].set_xlabel('Predicted'); axes[1].set_ylabel('Actual')
# Ensure good spacing between the subplots
plt.tight_layout()  
plt.show()

print('Average ACC for {} runs: {} +- {}'.format(total_runs,round(np.mean(accuracy_all),3),round(np.std(accuracy_all),3)))
print('Average TSS for {} runs: {} +- {}'.format(total_runs,round(np.mean(tss_all),3),round(np.std(tss_all),3)))
print('Average HSS for {} runs: {} +- {}'.format(total_runs,round(np.mean(hss_all),3),round(np.std(hss_all),3)))
# Out:
# Average ACC for 100 runs: 0.687 +- 0.091
# Average TSS for 100 runs: 0.374 +- 0.181
# Average HSS for 100 runs: 0.374 +- 0.181
